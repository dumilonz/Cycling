# %% [markdown]
# # Extract data
# The aim of this notebook is to extract professional cyclists' data for a season. Cleaning of the data will be done as well. Feature creation and analysis will be done on the next notebook.
#
# We extract all the riders at the beginning of the tour. Thereafter we itterate through each rider's profile on `procyclingstats.com` and scrape the races that they have partaken in, for the season. Thereafter, we itterate through all the races and extract their profiles (diificulty, uci status). The data is saved.

# %%
# imports
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
import re

# %%
RACE = 'tour-de-france'
YEAR = 2020
STAGE = 1
URL1 = 'https://www.procyclingstats.com/race/{}/{}/stage-{}/result/result'.format(RACE, YEAR, STAGE)
race_page = requests.get(URL1)
race_html = BeautifulSoup(race_page.content, 'html.parser')

# %%
class DataObject:
    def __init__(self, name, row_length):
        self.data = None
        self.data_added = False
        self.row_length = 0
        self.data_name = None

    def add_data(self, data):
        self.data = data
        self.data_added = True

# %%
def is_not_int(value):
    try:
        int(value)
        return False
    except ValueError:
        return True

def get_text(cell):
    ''' Return the text from the html cell. '''
    # some cells have a span or hyperlink element with text in it
    if cell.a != None:
        url = cell.a.get('href')
        if url.startswith('rider/') or url.startswith('race/'):
            return url, cell.a.get_text()
        return cell.a.get_text()
    elif cell.span != None:
        return cell.span.get_text()
    else:
        return cell.get_text()
    
def get_stage_data(html, data_row_length, print_row=False):
    # all the racers are in a table data cell ('td')
    row_cells = html.find_all('td')
    data = {'stage': list(), 'gc': list(), 'green': list(), 'youth': list(), 'kom': list(), 'teams': list()}
    datasets = list(data.keys())
    data_id = 0
    row_length = data_row_length[datasets[data_id]]
    old_length = row_length
    data_obj = DataObject(datasets[data_id], row_length)
    last_list_length = 0
    
    temp_list = list()
    error_list = list()
    error_row = False
    
    row = list()
    last_ix = 1

    # itterate through all data cells and append their text values to a row
    for row_ix, cell in enumerate(row_cells):
        
        text = get_text(cell)
        if type(text) is type('str'):
            row.append(text)
        else:
            row.append(text[0])
            row.append(text[1])
            
        if len(row) == 1:
            not_int = is_not_int(row[0])
            
            if not_int:
                print('Error row: {}'.format(row[0]))
                error_row = True
            
            if not not_int and int(row[0]) == 1 and len(temp_list) != 0:
                print('UPDATING 1: {} has {} participants'.format(datasets[data_id], len(temp_list)))
                ds = datasets[data_id]
                data[ds] = temp_list

                old_length = row_length
                
                data_id += 1
                temp_list = list()
                last_ix = 1
                error_row = False
                try:
                    row_length = data_row_length[datasets[data_id]]
                except KeyError:
                    break
        #print(error_row)
        if error_row and len(row) == old_length:
            row.append(row[0])
            row[0] = last_ix
            print('ERROR: {}'.format(row))

            temp_list.append(row)

            # TODO: change to temp list
#                error_list.append(row)
#                error_row = False
            row = list()
        elif not error_row and len(row) == row_length:
            # 'row_length' data cells make an entire row
            if print_row:
                print(row)
            # data list gets saved in data subset
            pos = int(row[0])
            # DQ/ DNF/ OL column
            row.append(np.nan)
            temp_list.append(row)
            last_ix = pos + 1
            row = list()
                
    print('UPDATING 1:{} has {} participants'.format(datasets[data_id], len(temp_list)))
    ds = datasets[data_id]
    data[ds] = temp_list
    return data

data_row_length = {'stage': 11, 'gc': 9, 'green': 8, 'youth': 9, 'kom': 8, 'teams': 4}
data = get_stage_data(race_html, data_row_length)
# Out:
# Error row: OTL
# ERROR: [176, '', '+ -3:46:13', '155', 'rider/john-degenkolb', ' Degenkolb John', '31', 'Lotto Soudal', '', '', '-', 'OTL']
# UPDATING 1: stage has 176 participants
# UPDATING 1: gc has 175 participants
# UPDATING 1: green has 24 participants
# UPDATING 1: youth has 26 participants
# UPDATING 1: kom has 3 participants
# UPDATING 1:teams has 22 participants

# %%
def fix_time(data, time_col):
    tdf = data[data[time_col] == ',,'][[time_col]]
    to_change_ix = list(tdf.index)
    data.loc[data.index.isin(to_change_ix), time_col] = None
    data[time_col] = data[time_col].fillna(method='ffill')
    return data

stage_df = pd.DataFrame(data['stage'], columns=['stagePos', 'gcPos', 'timeAdd', 'bib', 'url', 'name', 'age', 'team', 'uciStg','stagePnt', 'stageTime', 'DNF'])
stage_df = fix_time(stage_df, 'stageTime')
stage_df = stage_df.set_index('bib')

gc_df = pd.DataFrame(data['gc'], columns=['gcPos', 'bib', 'url', 'name', 'age', 'team', 'uciGc', 'time', 'more', 'DNF'])
gc_df = gc_df[['bib', 'uciGc']].set_index('bib')

green_df = pd.DataFrame(data['green'], columns=['greenPos', 'bib', 'url', 'name', 'age', 'team', 'greenPnts', 'pntsChng', 'DNF'])
green_df = green_df[['bib', 'greenPos', 'greenPnts']].set_index('bib')

youth_df = pd.DataFrame(data['youth'], columns=['youthPos', 'gcPos', 'timeAdd', 'bib', 'url', 'name', 'age', 'team', 'youthTime', 'DNF'])[['bib', 'youthPos', 'youthTime']]
youth_df = fix_time(youth_df, 'youthTime')
youth_df = youth_df.set_index('bib')

kom_df = pd.DataFrame(data['kom'], columns=['komPos', 'bib', 'url', 'name', 'age', 'team', 'komPnts',  'pntsChnge', 'DNF'])
kom_df = kom_df[['bib', 'komPos', 'komPnts']].set_index('bib')

teams_df = pd.DataFrame(data['teams'], columns=['teamPos', 'change', 'teamName', 'teamTime', 'DNF'])
teams_df = teams_df[['teamPos', 'teamName', 'teamTime']]

df = pd.concat([stage_df, gc_df, green_df, youth_df, kom_df], axis=1, sort=False)
df.head()
# Out:
#     stagePos gcPos timeAdd                       url                 name age  \
# 135        1     1   +0:00  rider/alexander-kristoff   Kristoff Alexander  33
# 105        2     2   +0:04       rider/mads-pedersen        Pedersen Mads  24
# 203        3     3   +0:06            rider/cees-bol             Bol Cees  25
# 43         4     4   +0:10         rider/sam-bennett          Bennett Sam  29
# 21         5     5   +0:10         rider/peter-sagan          Sagan Peter  30
#
#                         team uciStg stagePnt stageTime  DNF uciGc greenPos  \
# 135        UAE-Team Emirates    120      100   3:46:23  NaN    25        1
# 105         Trek - Segafredo     50       70   3:46:23  NaN              2
# 203              Team Sunweb     25       50   3:46:23  NaN              6
# 43   Deceuninck - Quick Step     15       40   3:46:23  NaN              4
# 21          BORA - hansgrohe      5       32   3:46:23  NaN              3
#
#     greenPnts youthPos youthTime komPos komPnts
# 135        59      NaN       NaN    NaN     NaN
# 105        30        1   3:46:17    NaN     NaN
# 203        20        2      0:02    NaN     NaN
# 43         28      NaN       NaN    NaN     NaN
# 21         29      NaN       NaN    NaN     NaN

# %%
try:
    print(df.DNF.unique())

    for finish_error in df.DNF.unique():
        if finish_error is not np.nan:
            df[finish_error] = 0

            df.loc[df.DNF == finish_error, [finish_error]] = 1
    df = df.drop(['DNF'], axis=1)
except: 
    print('')

df['youth'] = 1
df.loc[df.youthTime.isnull(), ['youth']] = 0
# make the dataframe
df.name = df.name.str.upper()
df.team = df.team.str.upper()

print('There were {} cyclists that finished stage 1'.format(df.shape[0]))
df.head()
# Out:
# [nan 'OTL']
# There were 176 cyclists that finished stage 1
#     stagePos gcPos timeAdd                       url                 name age  \
# 135        1     1   +0:00  rider/alexander-kristoff   KRISTOFF ALEXANDER  33
# 105        2     2   +0:04       rider/mads-pedersen        PEDERSEN MADS  24
# 203        3     3   +0:06            rider/cees-bol             BOL CEES  25
# 43         4     4   +0:10         rider/sam-bennett          BENNETT SAM  29
# 21         5     5   +0:10         rider/peter-sagan          SAGAN PETER  30
#
#                         team uciStg stagePnt stageTime uciGc greenPos  \
# 135        UAE-TEAM EMIRATES    120      100   3:46:23    25        1
# 105         TREK - SEGAFREDO     50       70   3:46:23              2
# 203              TEAM SUNWEB     25       50   3:46:23              6
# 43   DECEUNINCK - QUICK STEP     15       40   3:46:23              4
# 21          BORA - HANSGROHE      5       32   3:46:23              3
#
#     greenPnts youthPos youthTime komPos komPnts  OTL  youth
# 135        59      NaN       NaN    NaN     NaN    0      0
# 105        30        1   3:46:17    NaN     NaN    0      1
# 203        20        2      0:02    NaN     NaN    0      1
# 43         28      NaN       NaN    NaN     NaN    0      0
# 21         29      NaN       NaN    NaN     NaN    0      0

# %% [markdown]
# ## Create dataframes
# We are going to separate the data frame above into 3 more succinct dataframes.
#
# - `riders_df` that contians the 175 riders' personal infomration.
# - `stages_df` that containes that stages competed in by all the 175 riders in the past season
# - `races_df` that contains the information about the races that the 175 riders competed in in the past season (a race can have multiple stages)

# %%
riders_df = df[['name', 'age', 'url', 'team']]
riders_df = riders_df.sort_values('name')
riders_df['riderID'] = range(riders_df.shape[0])
riders_df = riders_df.set_index('riderID')
riders_df.head()
# Out:
#                         name age                       url  \
# riderID
# 0         ALAPHILIPPE JULIAN  28  rider/julian-alaphilippe
# 1              AMADOR ANDREY  34       rider/andrey-amador
# 2             ANACONA WINNER  32      rider/winner-anacona
# 3               ARNDT NIKIAS  28        rider/nikias-arndt
# 4                  ARU FABIO  30           rider/fabio-aru
#
#                             team
# riderID
# 0        DECEUNINCK - QUICK STEP
# 1               INEOS GRENADIERS
# 2              TEAM ARKÉA SAMSIC
# 3                    TEAM SUNWEB
# 4              UAE-TEAM EMIRATES

# %%
def find_races(url, rider_id, rider_name):
    ''' Extract all the races in the season for the rider on the rider's profile (url)'''
    page = requests.get(url)
    rider_html = BeautifulSoup(page.content, 'html.parser')
    results_html = rider_html.body.tbody
    # all races in data rows
    rows = results_html.find_all('tr')

    races = list()
    for row in rows:
        items = row.find_all('td')
        # extract text values from data cell
        row = list()
        for item in items:
            text = get_text(item)
            if type(text) is type('str'):
                row.append(text)
            else:
                row.append(text[0])
                row.append(text[1])
        races.append(row)
    df = pd.DataFrame(races, columns=['date', 'stagePos', 'gcPos', 'unknown', 'url', 'stage', 'distance', 'pcs', 'uci', 'more'])
    print('"{}" competed in {} stages'.format(rider_name, df.shape[0]))
    df['riderID'] = rider_id
    return df

# initialise list of dataframes
stages_list = list()
# itterate through each cyclist and add his races for the season
# to a list of dataframes
for ix, row in riders_df.iterrows():
    print('{} of {}'.format(ix, riders_df.shape[0]))
    url = row['url']
    name = row['name']
    rider_url = 'https://www.procyclingstats.com/{}'.format(url)
    rider_df = find_races(rider_url, ix, name)
    stages_list.append(rider_df)
# Out:
# 0 of 176
# " ALAPHILIPPE JULIAN" competed in 50 stages
# 1 of 176
# " AMADOR ANDREY" competed in 32 stages
# 2 of 176
# " ANACONA WINNER" competed in 48 stages
# 3 of 176
# " ARNDT NIKIAS" competed in 39 stages
# 4 of 176
# " ARU FABIO" competed in 36 stages
# 5 of 176
# " ASGREEN KASPER" competed in 47 stages
# 6 of 176
# " BARDET ROMAIN" competed in 55 stages
# 7 of 176
# " BARGUIL WARREN" competed in 40 stages
# 8 of 176
# " BARTHE CYRIL" competed in 55 stages
# 9 of 176
# " BAUER JACK" competed in 36 stages
# 10 of 176
# " BENNETT GEORGE" competed in 42 stages
# 11 of 176
# " BENNETT SAM" competed in 53 stages
# 12 of 176
# " BENOOT TIESJ" competed in 31 stages
# 13 of 176
# " BERNAL EGAN" competed in 46 stages
# 14 of 176
# " BETTIOL ALBERTO" competed in 35 stages
# 15 of 176
# " BEWLEY SAM" competed in 32 stages
# 16 of 176
# " BILBAO PELLO" competed in 53 stages
# 17 of 176
# " BOASSON HAGEN EDVALD" competed in 38 stages
# 18 of 176
# " BOL CEES" competed in 33 stages
# 19 of 176
# " BONIFAZIO NICCOLÒ" competed in 40 stages
# 20 of 176
# " BONNET WILLIAM" competed in 14 stages
# 21 of 176
# " BUCHMANN EMANUEL" competed in 25 stages
# 22 of 176
# " BURGAUDEAU MATHIEU" competed in 37 stages
# 23 of 176
# " CALMEJANE LILIAN" competed in 47 stages
# 24 of 176
# " CARAPAZ RICHARD" competed in 39 stages
# 25 of 176
# " CARTHY HUGH" competed in 27 stages
# 26 of 176
# " CARUSO DAMIANO" competed in 45 stages
# 27 of 176
# " CASTROVIEJO JONATHAN" competed in 40 stages
# 28 of 176
# " CATALDO DARIO" competed in 34 stages
# 29 of 176
# " CAVAGNA RÉMI" competed in 50 stages
# 30 of 176
# " CHAVES ESTEBAN" competed in 41 stages
# 31 of 176
# " CHEREL MIKAËL" competed in 48 stages
# 32 of 176
# " CHEVALIER MAXIME" competed in 27 stages
# 33 of 176
# " COLBRELLI SONNY" competed in 38 stages
# 34 of 176
# " CONSONNI SIMONE" competed in 37 stages
# 35 of 176
# " COQUARD BRYAN" competed in 45 stages
# 36 of 176
# " COSNEFROY BENOÎT" competed in 55 stages
# 37 of 176
# " COUSIN JÉRÔME" competed in 42 stages
# 38 of 176
# " CRAS STEFF" competed in 26 stages
# 39 of 176
# " DEBUSSCHERE JENS" competed in 49 stages
# 40 of 176
# " DECLERCQ TIM" competed in 49 stages
# 41 of 176
# " DEGENKOLB JOHN" competed in 36 stages
# 42 of 176
# " DEVENYNS DRIES" competed in 39 stages
# 43 of 176
# " DUMOULIN TOM" competed in 27 stages
# 44 of 176
# " EDET NICOLAS" competed in 55 stages
# 45 of 176
# " EG NIKLAS" competed in 46 stages
# 46 of 176
# " ELISSONDE KENNY" competed in 52 stages
# 47 of 176
# " ERVITI IMANOL" competed in 26 stages
# 48 of 176
# " EWAN CALEB" competed in 47 stages
# 49 of 176
# " FORMOLO DAVIDE" competed in 32 stages
# 50 of 176
# " FRAILE OMAR" competed in 47 stages
# 51 of 176
# " FRISON FREDERIK" competed in 46 stages
# 52 of 176
# " GAUDU DAVID" competed in 47 stages
# 53 of 176
# " GAUTIER CYRIL" competed in 48 stages
# 54 of 176
# " GESCHKE SIMON" competed in 42 stages
# 55 of 176
# " GESINK ROBERT" competed in 31 stages
# 56 of 176
# " GIBBONS RYAN" competed in 46 stages
# 57 of 176
# " GILBERT PHILIPPE" competed in 37 stages
# 58 of 176
# " GOGL MICHAEL" competed in 47 stages
# 59 of 176
# " GREIPEL ANDRÉ" competed in 33 stages
# 60 of 176
# " GRELLIER FABIEN" competed in 43 stages
# 61 of 176
# " GROSSSCHARTNER FELIX" competed in 54 stages
# 62 of 176
# " HALLER MARCO" competed in 46 stages
# 63 of 176
# " HERMANS BEN" competed in 27 stages
# 64 of 176
# " HERRADA JESÚS" competed in 37 stages
# 65 of 176
# " HIGUITA SERGIO" competed in 45 stages
# 66 of 176
# " HIRSCHI MARC" competed in 34 stages
# 67 of 176
# " HIRT JAN" competed in 34 stages
# 68 of 176
# " HOFSTETTER HUGO" competed in 49 stages
# 69 of 176
# " HOULE HUGO" competed in 38 stages
# 70 of 176
# " IMPEY DARYL" competed in 41 stages
# 71 of 176
# " IZAGIRRE GORKA" competed in 39 stages
# 72 of 176
# " IZAGIRRE ION" competed in 40 stages
# 73 of 176
# " JANSEN AMUND GRØNDAHL" competed in 16 stages
# 74 of 176
# " JUNGELS BOB" competed in 44 stages
# 75 of 176
# " JUUL-JENSEN CHRISTOPHER" competed in 34 stages
# 76 of 176
# " KEUKELEIRE JENS" competed in 31 stages
# 77 of 176
# " KLUGE ROGER" competed in 50 stages
# 78 of 176
# " KOCH JONAS" competed in 41 stages
# 79 of 176
# " KREUZIGER ROMAN" competed in 44 stages
# 80 of 176
# " KRISTOFF ALEXANDER" competed in 41 stages
# 81 of 176
# " KUSS SEPP" competed in 37 stages
# 82 of 176
# " KWIATKOWSKI MICHAŁ" competed in 35 stages
# 83 of 176
# " KÄMNA LENNARD" competed in 50 stages
# 84 of 176
# " KÜNG STEFAN" competed in 43 stages
# 85 of 176
# " LADAGNOUS MATTHIEU" competed in 47 stages
# 86 of 176
# " LAENGEN VEGARD STAKE" competed in 44 stages
# 87 of 176
# " LANDA MIKEL" competed in 40 stages
# 88 of 176
# " LAPORTE CHRISTOPHE" competed in 24 stages
# 89 of 176
# " LATOUR PIERRE" competed in 46 stages
# 90 of 176
# " LEDANOIS KÉVIN" competed in 38 stages
# 91 of 176
# " LUTSENKO ALEXEY" competed in 40 stages
# 92 of 176
# " LÓPEZ MIGUEL ÁNGEL" competed in 37 stages
# 93 of 176
# " MADOUAS VALENTIN" competed in 39 stages
# 94 of 176
# " MARCATO MARCO" competed in 39 stages
# 95 of 176
# " MARTIN DAN" competed in 40 stages
# 96 of 176
# " MARTIN GUILLAUME" competed in 53 stages
# 97 of 176
# " MARTIN TONY" competed in 30 stages
# 98 of 176
# " MARTÍNEZ DANIEL FELIPE" competed in 35 stages
# 99 of 176
# " MAS ENRIC" competed in 42 stages
# 100 of 176
# " MEZGEC LUKA" competed in 39 stages
# 101 of 176
# " MOHORIČ MATEJ" competed in 40 stages
# 102 of 176
# " MOLARD RUDY" competed in 44 stages
# 103 of 176
# " MOLLEMA BAUKE" competed in 38 stages
# 104 of 176
# " MØRKØV MICHAEL" competed in 53 stages
# 105 of 176
# " MÜHLBERGER GREGOR" competed in 38 stages
# 106 of 176
# " NAESEN OLIVER" competed in 45 stages
# 107 of 176
# " NEILANDS KRISTS" competed in 35 stages
# 108 of 176
# " NIEUWENHUIS JORIS" competed in 18 stages
# 109 of 176
# " NIEVE MIKEL" competed in 38 stages
# 110 of 176
# " NIV GUY" competed in 34 stages
# 111 of 176
# " NIZZOLO GIACOMO" competed in 51 stages
# 112 of 176
# " OLIVEIRA NELSON" competed in 41 stages
# 113 of 176
# " OSS DANIEL" competed in 32 stages
# 114 of 176
# " PACHER QUENTIN" competed in 48 stages
# 115 of 176
# " PEDERSEN CASPER" competed in 30 stages
# 116 of 176
# " PEDERSEN MADS" competed in 49 stages
# 117 of 176
# " PEREZ ANTHONY" competed in 41 stages
# 118 of 176
# " PETERS NANS" competed in 48 stages
# 119 of 176
# " PINOT THIBAUT" competed in 54 stages
# 120 of 176
# " POELS WOUT" competed in 35 stages
# 121 of 176
# " POGAČAR TADEJ" competed in 45 stages
# 122 of 176
# " POLANC JAN" competed in 39 stages
# 123 of 176
# " POLITT NILS" competed in 44 stages
# 124 of 176
# " PORTE RICHIE" competed in 64 stages
# 125 of 176
# " POWLESS NEILSON" competed in 39 stages
# 126 of 176
# " POZZOVIVO DOMENICO" competed in 31 stages
# 127 of 176
# " PÉRICHON PIERRE-LUC" competed in 42 stages
# 128 of 176
# " PÖSTLBERGER LUKAS" competed in 39 stages
# 129 of 176
# " QUINTANA DAYER" competed in 41 stages
# 130 of 176
# " QUINTANA NAIRO" competed in 53 stages
# 131 of 176
# " REICHENBACH SÉBASTIEN" competed in 34 stages
# 132 of 176
# " REZA KÉVIN" competed in 47 stages
# 133 of 176
# " ROCHE NICOLAS" competed in 26 stages
# 134 of 176
# " ROGLIČ PRIMOŽ" competed in 27 stages
# 135 of 176
# " ROJAS JOSÉ JOAQUÍN" competed in 38 stages
# 136 of 176
# " ROLLAND PIERRE" competed in 43 stages
# 137 of 176
# " ROSA DIEGO" competed in 39 stages
# 138 of 176
# " ROWE LUKE" competed in 47 stages
# 139 of 176
# " RUSSO CLÉMENT" competed in 36 stages
# 140 of 176
# " SAGAN PETER" competed in 38 stages
# 141 of 176
# " SCHACHMANN MAXIMILIAN" competed in 42 stages
# 142 of 176
# " SCHÄR MICHAEL" competed in 41 stages
# 143 of 176
# " SICARD ROMAIN" competed in 43 stages
# 144 of 176
# " SIVAKOV PAVEL" competed in 51 stages
# 145 of 176
# " SKUJIŅŠ TOMS" competed in 31 stages
# 146 of 176
# " SOLER MARC" competed in 46 stages
# 147 of 176
# " SOUPE GEOFFREY" competed in 41 stages
# 148 of 176
# " STUYVEN JASPER" competed in 51 stages
# 149 of 176
# " SWIFT CONNOR" competed in 52 stages
# 150 of 176
# " SÁNCHEZ LUIS LEÓN" competed in 57 stages
# 151 of 176
# " TEJADA HAROLD" competed in 32 stages
# 152 of 176
# " THEUNS EDWARD" competed in 48 stages
# 153 of 176
# " TRENTIN MATTEO" competed in 53 stages
# 154 of 176
# " TURGIS ANTHONY" competed in 51 stages
# 155 of 176
# " URÁN RIGOBERTO" competed in 27 stages
# 156 of 176
# " VALGREN MICHAEL" competed in 46 stages
# 157 of 176
# " VALLS RAFAEL" competed in 29 stages
# 158 of 176
# " VALVERDE ALEJANDRO" competed in 55 stages
# 159 of 176
# " VENTURINI CLÉMENT" competed in 48 stages
# 160 of 176
# " VERONA CARLOS" competed in 34 stages
# 161 of 176
# " VIVIANI ELIA" competed in 48 stages
# 162 of 176
# " VUILLERMOZ ALEXIS" competed in 25 stages
# 163 of 176
# " WALSCHEID MAX" competed in 52 stages
# 164 of 176
# " YATES ADAM" competed in 27 stages
# 165 of 176
# " ZAKARIN ILNUR" competed in 27 stages
# 166 of 176
# "DE BUYST JASPER" competed in 37 stages
# 167 of 176
# "DE GENDT THOMAS" competed in 50 stages
# 168 of 176
# "DE LA CRUZ DAVID" competed in 43 stages
# 169 of 176
# "DE MARCHI ALESSANDRO" competed in 28 stages
# 170 of 176
# "KRAGH ANDERSEN SØREN" competed in 36 stages
# 171 of 176
# "VAN AERT WOUT" competed in 26 stages
# 172 of 176
# "VAN ASBROECK TOM" competed in 46 stages
# 173 of 176
# "VAN AVERMAET GREG" competed in 42 stages
# 174 of 176
# "VAN BAARLE DYLAN" competed in 43 stages
# 175 of 176
# "VAN GARDEREN TEJAY" competed in 33 stages

# %%
stages_ = pd.concat(stages_list).reset_index(drop=True)
print('{} stages have been loaded'.format(stages_.shape[0]))
# drop 2 unnecessary columns
stages_ = stages_.drop(['unknown', 'more'], axis=1)
stages_.head()
# Out:
# 7131 stages have been loaded
#        date stagePos gcPos                                url  \
# 0   › 20.09                  race/tour-de-france/2020/stage-1
# 1     09.09      147    45  race/tour-de-france/2020/stage-11
# 2     08.09      160    41  race/tour-de-france/2020/stage-10
# 3     06.09      160    38   race/tour-de-france/2020/stage-9
# 4     05.09       38    26   race/tour-de-france/2020/stage-8
#
#                                                stage distance pcs uci  riderID
# 0                                     Tour de France                         0
# 1           Stage 11 - Châtelaillon-Plage › Poitiers    167.5                0
# 2  Stage 10 - île d'Oléron (Le Château-d'Oléron) ...    168.5                0
# 3                             Stage 9 - Pau › Laruns      153                0
# 4                   Stage 8 - Cazères › Loudenvielle      141                0

# %%
def _get_unique_races(data):
    data.columns = ['race', 'url']
    num_races = len(data.race.unique())
    num_url = len(data.url.unique())
    
    if num_races == num_url:
        rdf = data.groupby(['race', 'url']).count()
        rdf = rdf.reset_index()
        rdf['cutUrl'] = rdf.apply(lambda x: x['url'][0: x['url'].rindex('/')], axis =1)
        rdf.index.name = 'raceIX'
        return rdf
    else:
        return None
        
def _add_race_id_to_data(races_df, all_data):
    if 'raceID' not in all_data.columns:
        print('Creating "raceID" collumn')
        all_data['raceID'] = np.nan
        
    for race_ix, race_row in races_df.iterrows():
        url_begin = race_row['cutUrl']
        all_data.loc[all_data.url.str.startswith(url_begin), 'raceID'] = race_ix
        
    return all_data

def create_races_df(data):
    ''' '''
    # multistage races 
    rdf = data[(data.distance == '') & (data.stagePos == '')][['stage', 'url']]
    rdf2 = _get_unique_races(rdf)
    data1 = _add_race_id_to_data(rdf2, data)
        
    # one day races
    odr = data1[data1.raceID.isnull()][['stage', 'url']]
    rdf3 = _get_unique_races(odr)
    data2 = _add_race_id_to_data(rdf3, data1)
    
    races_df = pd.concat([rdf2, rdf3], ignore_index=True)
    
    return races_df, data2
    
races_df, rhdf = create_races_df(stages_)
rhdf = rhdf.astype({'raceID': int})
print('There are {} unique races.\nThere are {} stages(s) without a raceID.'.format(races_df.shape[0], rhdf[rhdf.raceID.isnull()].shape[0]))
races_df.head()
# Out:
# Creating "raceID" collumn
# There are 79 unique races.
# There are 0 stages(s) without a raceID.
#                                         race  \
# 0                      Critérium du Dauphiné
# 1                                 Czech Tour
# 2                         Etoile de Bessèges
# 3                      Jayco Herald Sun Tour
# 4  La Route d'Occitanie - La Dépêche du Midi
#
#                                       url                          cutUrl
# 0              race/dauphine/2020/stage-1              race/dauphine/2020
# 1    race/czech-cycling-tour/2020/stage-1    race/czech-cycling-tour/2020
# 2    race/etoile-de-besseges/2020/stage-1    race/etoile-de-besseges/2020
# 3       race/herald-sun-tour/2020/stage-1       race/herald-sun-tour/2020
# 4  race/la-route-d-occitanie/2020/stage-1  race/la-route-d-occitanie/2020

# %%
rhdf.head()
# Out:
#        date stagePos gcPos                                url  \
# 0   › 20.09                  race/tour-de-france/2020/stage-1
# 1     09.09      147    45  race/tour-de-france/2020/stage-11
# 2     08.09      160    41  race/tour-de-france/2020/stage-10
# 3     06.09      160    38   race/tour-de-france/2020/stage-9
# 4     05.09       38    26   race/tour-de-france/2020/stage-8
#
#                                                stage distance pcs uci  \
# 0                                     Tour de France
# 1           Stage 11 - Châtelaillon-Plage › Poitiers    167.5
# 2  Stage 10 - île d'Oléron (Le Château-d'Oléron) ...    168.5
# 3                             Stage 9 - Pau › Laruns      153
# 4                   Stage 8 - Cazères › Loudenvielle      141
#
#    riderID  raceID
# 0        0      13
# 1        0      13
# 2        0      13
# 3        0      13
# 4        0      13

# %%
print(rhdf.shape)
# drop multi stage race heagings
rider_race_history_df = rhdf[(rhdf.distance != '') | (rhdf.stagePos != '')]
# drop end of stage race classifcation
# will be added in more detail
rider_race_history_df = rider_race_history_df[(rider_race_history_df.date != '') | (rider_race_history_df.gcPos != '')]
print(rider_race_history_df.shape)
rider_race_history_df.head()
# Out:
# (7131, 10)
# (5375, 10)
#     date stagePos gcPos                                url  \
# 1  09.09      147    45  race/tour-de-france/2020/stage-11
# 2  08.09      160    41  race/tour-de-france/2020/stage-10
# 3  06.09      160    38   race/tour-de-france/2020/stage-9
# 4  05.09       38    26   race/tour-de-france/2020/stage-8
# 5  04.09       12    11   race/tour-de-france/2020/stage-7
#
#                                                stage distance pcs uci  \
# 1           Stage 11 - Châtelaillon-Plage › Poitiers    167.5
# 2  Stage 10 - île d'Oléron (Le Château-d'Oléron) ...    168.5
# 3                             Stage 9 - Pau › Laruns      153
# 4                   Stage 8 - Cazères › Loudenvielle      141
# 5                          Stage 7 - Millau › Lavaur      168   6
#
#    riderID  raceID
# 1        0      13
# 2        0      13
# 3        0      13
# 4        0      13
# 5        0      13

# %%
stages_df = rider_race_history_df[['date', 'stage', 'url', 'distance']]
print(len(stages_df.groupby(['date']).count()))
print(len(stages_df.groupby(['stage']).count()))
print(len(stages_df.groupby(['url']).count()))
stages_df = stages_df.groupby(['stage', 'url', 'date', 'distance']).count()
stages_df = stages_df.reset_index()
stages_df.index.name = 'stagesID'
print(stages_df.shape)
stages_df.head()
# Out:
# 92
# 192
# 192
# (192, 4)
#                                               stage  \
# stagesID
# 0                   Bretagne Classic - Ouest-France
# 1                 Cadel Evans Great Ocean Road Race
# 2         Circuito de Getxo-Memorial Hermanos Otxoa
# 3                                Clasica de Almeria
# 4         European Continental Championships  - ITT
#
#                                                         url   date distance
# stagesID
# 0                         race/bretagne-classic/2020/result  25.08   247.75
# 1                         race/great-ocean-race/2020/result  02.02    171.1
# 2                        race/circuito-de-getxo/2020/result  02.08      177
# 3                       race/clasica-de-almeria/2020/result  16.02    187.6
# 4         race/uec-road-european-championships-itt/2020/...  24.08     25.6

# %%
rider_race_history_df['stageID'] = np.nan

for stage_ix, stage_row in stages_df.iterrows():
    stage_url = stage_row['url']
    rider_race_history_df.loc[rider_race_history_df.url == stage_url, 'stageID'] = stage_ix
    
print('{} races are unlabelled'.format(rider_race_history_df[rider_race_history_df.stageID.isnull()].shape[0]))
race_history_df = rider_race_history_df.drop(['url', 'stage', 'distance', 'date'], axis=1)
race_history_df = race_history_df.astype({'stageID': int})
race_history_df.head()
# Out:
# 0 races are unlabelled
#   stagePos gcPos pcs uci  riderID  raceID  stageID
# 1      147    45                0      13       76
# 2      160    41                0      13       75
# 3      160    38                0      13      186
# 4       38    26                0      13      184
# 5       12    11   6            0      13      180

# %%
stages_df.head()
# Out:
#                                               stage  \
# stagesID
# 0                   Bretagne Classic - Ouest-France
# 1                 Cadel Evans Great Ocean Road Race
# 2         Circuito de Getxo-Memorial Hermanos Otxoa
# 3                                Clasica de Almeria
# 4         European Continental Championships  - ITT
#
#                                                         url   date distance
# stagesID
# 0                         race/bretagne-classic/2020/result  25.08   247.75
# 1                         race/great-ocean-race/2020/result  02.02    171.1
# 2                        race/circuito-de-getxo/2020/result  02.08      177
# 3                       race/clasica-de-almeria/2020/result  16.02    187.6
# 4         race/uec-road-european-championships-itt/2020/...  24.08     25.6

# %%
all_stages = list()
for stage_ix, stage  in stages_df.iterrows():
    url = stage['url']
    stage_url = 'https://www.procyclingstats.com/{}'.format(url)
    print('{} of {} for \'{}\''.format(stage_ix, stages_df.shape[0], url))
    page = requests.get(stage_url)
    stage_html = BeautifulSoup(page.content, 'html.parser')
    
    res_ = stage_html.find_all("div", class_="res-right")
    res_text = res_[0].find_all(text=True)
    stage_info = list()
    mountains = list()
    found_race_rank = False
    pnts_quality_found = False
    for tix, text in enumerate(res_text):
        web_regex = re.search('(www.(.)+\.(.)+)+', text) \
                        or re.search('((.)+\.com(.)+)+', text) \
                        or re.search('((.)+\.(\w)*(\d)*/)', text) \
                        or 'googletag.cmd.push(' in text
        #if web_regex: print(text)
        if text not in ['Race information', 'Date: ', 'Avg. speed winner:', 'rd', \
                        'Race category: ', 'Parcours type:', 'PCS point scale:', \
                        ' ', 'Start/finish:', ' › ', 'Climbs: ', ', ', 'Race profile', \
                        'Finish photo', 'Finish photo', 'LiveStats', 'Websites:', \
                        'Race ranking position', 'ranking', 'th', 'nd', 'st', '\n', \
                        'breakdown', 'Position and points as on startdate of race.'] \
        and not web_regex:
            if len(stage_info) <= 6 or found_race_rank:
                stage_info.append(text)
                if re.search('(\d)* pnt', text):
                    break
            else:
            #elif not found_race_rank:
                if is_not_int(text):
                    mountains.append(text)
                    #print(mountains)
                else:
                    stage_info.append(mountains)
                    stage_info.append(len(mountains))
                    stage_info.append(text)
                    found_race_rank = True
        
        if text is 'ranking':
            break
    #print(stage_info)
    stage_info = list(stage) + stage_info
    all_stages.append(stage_info)
# Out:
# 0 of 192 for 'race/bretagne-classic/2020/result'
# 1 of 192 for 'race/great-ocean-race/2020/result'
# 2 of 192 for 'race/circuito-de-getxo/2020/result'
# 3 of 192 for 'race/clasica-de-almeria/2020/result'
# 4 of 192 for 'race/uec-road-european-championships-itt/2020/result'
# 5 of 192 for 'race/uec-road-european-championships/2020/result'
# 6 of 192 for 'race/les-boucles-du-dus-ardeche/2020/result'
# 7 of 192 for 'race/giro-dell-emilia/2020/result'
# 8 of 192 for 'race/gran-piemonte/2020/result'
# 9 of 192 for 'race/gran-trittico-lombardo/2020/result'
# 10 of 192 for 'race/gp-d-ouverture/2020/result'
# 11 of 192 for 'race/gp-de-la-ville-de-lillers/2020/result'
# 12 of 192 for 'race/grote-prijs-jean-pierre-monsere/2020/result'
# 13 of 192 for 'race/il-lombardia/2020/result'
# 14 of 192 for 'race/kuurne-brussel-kuurne/2020/result'
# 15 of 192 for 'race/gp-samyn/2020/result'
# 16 of 192 for 'race/malaysian-international-classic-race/2020/result'
# 17 of 192 for 'race/milano-sanremo/2020/result'
# 18 of 192 for 'race/milano-torino/2020/result'
# 19 of 192 for 'race/mont-ventoux-denivele-challenge/2020/result'
# 20 of 192 for 'race/nc-austria/2020/result'
# 21 of 192 for 'race/nc-belgium-itt/2020/result'
# 22 of 192 for 'race/nc-colombia-itt/2020/result'
# 23 of 192 for 'race/nc-colombia/2020/result'
of 192 for 'race/la-tropicale-amissa-bongo/2020/stage-6'
# 176 of 192 for 'race/paris-nice/2020/stage-6'
# 177 of 192 for 'race/tour-de-langkawi/2020/stage-6'
# 178 of 192 for 'race/colombia-21/2020/stage-6'
# 179 of 192 for 'race/tour-de-langkawi/2020/stage-7'
# 180 of 192 for 'race/tour-de-france/2020/stage-7'
# 181 of 192 for 'race/paris-nice/2020/stage-7'
# 182 of 192 for 'race/la-tropicale-amissa-bongo/2020/stage-7'
# 183 of 192 for 'race/vuelta-ciclista-a-la-provincia-de-san-juan/2020/stage-7'
# 184 of 192 for 'race/tour-de-france/2020/stage-8'
# 185 of 192 for 'race/tour-de-langkawi/2020/stage-8'
# 186 of 192 for 'race/tour-de-france/2020/stage-9'
# 187 of 192 for 'race/strade-bianche/2020/result'
# 188 of 192 for 'race/trofeo-cala-millor/2020/result'
# 189 of 192 for 'race/trofeo-laigueglia/2020/result'
# 190 of 192 for 'race/16th-challenge-volta-a-mallorca/2020/result'
# 191 of 192 for 'race/deia-trophy/2020/result'

# %%
stgs_df = pd.DataFrame(all_stages, columns=['stageName', 'url', 'date', 'distance', \
                                     'dateFull', 'averageSpeed', 'raceCtgr', \
                                     'parcoursType', 'PCSPointScale', 'start',\
                                     'end', 'mountains', 'numMount', 'raceRank', \
                                     'racePoints'])
stgs_df['racePoints'] = stgs_df.racePoints.str.replace('pnt', '')
stgs_df = stgs_df.drop('raceRank',  axis=1)
stgs_df.head()
# Out:
#                                    stageName  \
# 0            Bretagne Classic - Ouest-France
# 1          Cadel Evans Great Ocean Road Race
# 2  Circuito de Getxo-Memorial Hermanos Otxoa
# 3                         Clasica de Almeria
# 4  European Continental Championships  - ITT
#
#                                                  url   date distance  \
# 0                  race/bretagne-classic/2020/result  25.08   247.75
# 1                  race/great-ocean-race/2020/result  02.02    171.1
# 2                 race/circuito-de-getxo/2020/result  02.08      177
# 3                race/clasica-de-almeria/2020/result  16.02    187.6
# 4  race/uec-road-european-championships-itt/2020/...  24.08     25.6
#
#               dateFull averageSpeed    raceCtgr parcoursType   PCSPointScale  \
# 0     25th August 2020   41.15 km/h   Men Elite           45          1.WT.B
# 1    2nd February 2020   41.76 km/h   Men Elite           53          1.WT.C
# 2      2nd August 2020   42.29 km/h   Men Elite           0*             1.1
# 3   16th February 2020   42.63 km/h   Men Elite           0*            1.HC
# 4     24th August 2020   50.69 km/h   Men Elite           0*  UCI.Cont.Ch.TT
#
#              start              end  \
# 0           Plouay           Plouay
# 1          Geelong          Geelong
# 2            Getxo            Getxo
# 3  Roquetas de Mar  Roquetas de Mar
# 4           Plouay           Plouay
#
#                                            mountains  numMount racePoints
# 0  [Restergal, Côte du Lezot, Restergal, Côte de ...       5.0       390
# 1                                                 []       0.0       395
# 2                                                 []       0.0       238
# 3                                                 []       0.0       397
# 4                                                 []       0.0        86

# %%
errors = stgs_df[stgs_df.racePoints.isnull()]
errors
# Out:
#                                           stageName  \
# 9                            Gran Trittico Lombardo
# 17                                   Milano-Sanremo
# 21             National Championships Belgium - ITT
# 30         National Championships Italy - Road Race
# 68   Stage 1 - Saint-Affrique › Cazouls-lès-Béziers
# 81           Stage 2 - Carcassonne › Cap Découverte
# 121        Stage 3 - Saint-Gaudens › Col de Beyrède
# 142                 Stage 4 - Lectoure › Rocamadour
# 187                                  Strade Bianche
#
#                                          url   date distance  \
# 9    race/gran-trittico-lombardo/2020/result  03.08    199.7
# 17           race/milano-sanremo/2020/result  08.08      305
# 21           race/nc-belgium-itt/2020/result  20.08     42.1
# 30                 race/nc-italy/2020/result  23.08    253.8
# 68    race/la-route-d-occitanie/2020/stage-1  01.08    189.5
# 81    race/la-route-d-occitanie/2020/stage-2  02.08    182.5
# 121   race/la-route-d-occitanie/2020/stage-3  03.08    163.5
# 142   race/la-route-d-occitanie/2020/stage-4  04.08      195
# 187          race/strade-bianche/2020/result  01.08      184
#
#               dateFull averageSpeed    raceCtgr parcoursType    PCSPointScale  \
# 9      3rd August 2020   42.64 km/h   Men Elite           77             1.HC
# 17     8th August 2020   41.96 km/h   Men Elite           48           1.WT.A
# 21    20th August 2020   50.35 km/h   Men Elite           0*  Nationals.C3.TT
# 30    23rd August 2020   43.68 km/h   Men Elite           0*     Nationals.C3
# 68     1st August 2020   41.35 km/h   Men Elite           0*        2.1.Stage
# 81     2nd August 2020   41.73 km/h   Men Elite           32        2.1.Stage
# 121    3rd August 2020   35.45 km/h   Men Elite          299        2.1.Stage
# 142    4th August 2020   44.41 km/h   Men Elite           67        2.1.Stage
# 187    1st August 2020   36.93 km/h   Men Elite          104           1.WT.C
#
#                                 start                  end mountains  \
# 9                             Legnano               Varese      None
# 17                             Milano              Sanremo      None
# 21                Koksijde › Koksijde                  112      None
# 30    Bassano del Grappa › Cittadella                   40      None
# 68                     Saint-Affrique  Cazouls-lès-Béziers      None
# 81                        Carcassonne       Cap Découverte      None
# 121                     Saint-Gaudens       Col de Beyrède      None
# 142                          Lectoure           Rocamadour      None
# 187                             Siena                Siena      None
#
#      numMount racePoints
# 9         NaN       None
# 17        NaN       None
# 21        NaN       None
# 30        NaN       None
# 68        NaN       None
# 81        NaN       None
# 121       NaN       None
# 142       NaN       None
# 187       NaN       None

# %%
#print(stgs_df[stgs_df.index.isin(errors.index)])
e_ix = list(errors.index)
stgs_df.loc[e_ix, 'mountains'] = 0
stgs_df.loc[e_ix, 'numMount'] = 0
stgs_df.loc[e_ix, 'racePoints'] = 0

starts_and_ends = errors[errors.start.str.contains('›')]
for er_ix, error_row in starts_and_ends.iterrows():
    start_end = error_row['start']
    start_ix = start_end.find('›')
    
    start = start_end[:start_ix]
    end = start_end[start_ix + 1:]
    racePnts = error_row['end']
    
    stgs_df.loc[er_ix, 'start'] = start
    stgs_df.loc[er_ix, 'end'] = end
    stgs_df.loc[er_ix, 'racePoints'] = racePnts

stgs_df[stgs_df.racePoints.isnull()]
# Out:
# Empty DataFrame
# Columns: [stageName, url, date, distance, dateFull, averageSpeed, raceCtgr, parcoursType, PCSPointScale, start, end, mountains, numMount, racePoints]
# Index: []

# %%
#stage_url = 'https://www.procyclingstats.com/race/tour-de-france/2020/stage-3'
#stage_url = 'https://www.procyclingstats.com/race/nc-switzerland-itt/2020/result'
stage_url = 'https://www.procyclingstats.com/race/gran-trittico-lombardo/2020/result'
page = requests.get(stage_url)
stage_html = BeautifulSoup(page.content, 'html.parser')
print('(ITT)' in str(stage_html.h2), str(stage_html.h2))

res_ = stage_html.find_all("div", class_="res-right")
#res_[0]
#data_row_length = data_row_length = {'stage': 11, 'gc': 11, 'green': 10, 'youth': 11, 'kom': 10, 'teams': 6}
#data = get_stage_data(stage_html, data_row_length, True)
# Out:
# False <h2><span class="yearmob hide">2020  </span><span class="blue">One day race</span>  »  <span class="red">Legnano  ›  Varese  </span> <span class="red distance">(199.7k)</span></h2>

# %%
res_[0].find_all(text=True)
# Out:
# ['Race information',
#  'Date: ',
#  ' 3rd August 2020',
#  'Avg. speed winner:',
#  ' 42.64 km/h',
#  'Race category: ',
#  ' Men Elite',
#  'Parcours type:',
#  ' ',
#  ' ',
#  '77',
#  'PCS point scale:',
#  ' ',
#  '1.HC',
#  ' ',
#  'Start/finish:',
#  ' ',
#  'Legnano',
#  ' › ',
#  'Varese',
#  'Race profile',
#  'Websites:',
#  ' ',
#  'www.tritticolombardo.it/',
#  '\n',
#  "\n        googletag.cmd.push(function() { googletag.display('div-gpt-ad-1502360547318-0'); });\n        ",
#  '\n',
#  '\n']

# %%
stage_df = pd.DataFrame(data['gc'], gc_col = ['gcPos', 'prevGcPos', 'gcChng', 'bib', 'url', 'name', 'age', 'team', 'uciGc', 'gcTime', 'more'])
stage_df.head()
# Out:
#   stagePos posChange                       url                 name age  \
# 0        1                 rider/arnaud-demare        Démare Arnaud  28
# 1        2                 rider/bryan-coquard        Coquard Bryan  28
# 2        3            rider/julian-alaphilippe   Alaphilippe Julian  28
# 3        4             rider/clement-venturini    Venturini Clément  26
# 4        5                rider/anthony-turgis       Turgis Anthony  26
#
#                              teamName  uci pnts stageTime
# 0                      Groupama - FDJ  100   15   5:38:27
# 1  B&B Hotels - Vital Concept p/b KTM   75   10        ,,
# 2             Deceuninck - Quick Step   60    7        ,,
# 3                    AG2R La Mondiale   50    4      0:05
# 4           Team Total Direct Energie   40    2        ,,

# %%
ONE_DAY_RACE = 0
FIRST_STAGE_IN_TOUR = 1
OTHER_TOUR_STAGE = 2
ITT = 3

def build_df(data, result_type):
    if result_type == ONE_DAY_RACE:
        stage_col = ['stagePos', 'gcPos', 'url', 'name', 'age', 'teamName', 'uciStage', 'pnt', 'stageTime']
    elif result_type == ITT:
        stage_col = ['stagePos', 'gcPos', 'timeAdd', 'bib', 'url', 'name', 'age', 'teamName', 'uciStage','pnt', 'stgAvgPace', 'stageTime']
    elif result_type == FIRST_STAGE_IN_TOUR:
        stage_col = ['stagePos', 'gcPos', 'timeAdd', 'bib', 'url', 'name', 'age', 'teamName', 'uciStage','pnt', 'stageTime']
        gc_col = ['gcPos', 'bib', 'url', 'name', 'age', 'team', 'uciGc', 'gcTime', 'more']
        green_col = ['greenPos', 'bib', 'url', 'name', 'age', 'team', 'greenPnts', 'greenPntsChng']
        youth_col = ['youthPos', 'gcPos', 'timeAdd', 'bib', 'url', 'name', 'age', 'team', 'youthTime']
        kom_col = ['komPos', 'bib', 'url', 'name', 'age', 'team', 'komPnts',  'komPntsChng']
        teams_col = ['teamPos', 'empty', 'teamName', 'teamTime']
    elif result_type == OTHER_TOUR_STAGE:
        stage_col = ['stagePos', 'gcPos', 'gcTime', 'bib', 'url', 'name', 'age', 'teamName', 'uciStage','pnt', 'stageTime']
        gc_col = ['gcPos', 'prevGcPos', 'gcChng', 'bib', 'url', 'name', 'age', 'team', 'uciGc', 'gcTime', 'more']
        green_col = ['greenPos', 'prevGreenPos', 'greenChng', 'bib', 'url', 'name', 'age', 'team', 'greenPnts', 'greenPntsChng']
        youth_col = ['youthPos', 'prevYouthPos', 'youthChng', 'gcPos', 'gcTime', 'bib', 'url', 'name', 'age', 'team', 'youthTime']
        kom_col = ['komPos', 'prevKomPos', 'komChng', 'bib', 'url', 'name', 'age', 'team', 'komPnts',  'komPntsChng']
        teams_col = ['teamPos', 'prevTeamPos', 'teamChng', 'empty', 'teamName', 'teamTime']
    
    stage_df = pd.DataFrame(data['stage'], columns=stage_col)
    stage_df = fix_time(stage_df, 'stageTime')
    
    if result_type in [FIRST_STAGE_IN_TOUR, OTHER_TOUR_STAGE]:
        # one day races only have 1 data frame
        stage_df = stage_df.set_index('bib')
        gc_df = pd.DataFrame(data['gc'], columns=gc_col)
        gc_df = gc_df[['bib', 'uciGc']].set_index('bib')

        green_df = pd.DataFrame(data['green'], columns=green_col)
        green_df = green_df[['bib', 'greenPos', 'greenPnts']].set_index('bib')

        youth_df = pd.DataFrame(data['youth'], columns=youth_col)
        youth_df = youth_df[['bib', 'youthPos', 'youthTime']].set_index('bib')
        youth_df = fix_time(youth_df, 'youthTime')

        kom_df= pd.DataFrame(data['kom'], columns=kom_col)
        kom_df = kom_df[['bib', 'komPos', 'komPnts']].set_index('bib')

        team_df = pd.DataFrame(data['teams'], columns=teams_col)
        team_df = team_df[['teamPos', 'teamName', 'teamTime']]

        df = pd.concat([stage_df, gc_df, green_df, youth_df, kom_df], axis=1, sort=False)
        return df
    else:
        return stage_df

df = build_df(data, ITT)
df.head()
# Out:
#   stagePos gcPos timeAdd bib                          url  \
# 0        1     2   +0:58  98   rider/soren-kragh-andersen
# 1        2     1   +0:00  37  rider/maximilian-schachmann
# 2        3    23   +2:16  42         rider/kasper-asgreen
# 3        4    85  +14:52  64        rider/thomas-de-gendt
# 4        5    29   +3:41  82           rider/pello-bilbao
#
#                      name age                 teamName uciStage pnt  \
# 0    Kragh Andersen Søren  25              Team Sunweb       60  50
# 1   Schachmann Maximilian  26         BORA - hansgrohe       25  30
# 2          Asgreen Kasper  25  Deceuninck - Quick Step       10  18
# 3         De Gendt Thomas  33             Lotto Soudal           13
# 4            Bilbao Pello  30        Bahrain - McLaren           10
#
#   stgAvgPace stageTime
# 0     48.064     18:51
# 1     47.810      0:06
# 2     47.559      0:12
# 3     47.517      0:13
# 4     47.435      0:15

# %%
# get the points classifications
def get_points(url):
    ''' Extract all the races in the season for the rider on the rider's profile (url)'''
    page = requests.get(url)
    stage_html = BeautifulSoup(page.content, 'html.parser')
    
    if 'One day race' in str(stage_html.h2):
        print('ONE DAY RACE')
        data_row_length = {'stage': 9}
        result_type = ONE_DAY_RACE
    elif '(ITT)' in str(stage_html.h2):
        print('(ITT)')
        data_row_length = {'stage': 12}
        result_type = ITT
    elif url.endswith('/result') or url.endswith('/stage-1'):
        result_type = FIRST_STAGE_IN_TOUR
        data_row_length = {'stage': 11, 'gc': 9, 'green': 8, 'youth': 9, 'kom': 8, 'teams': 4}
    else:
        result_type = OTHER_TOUR_STAGE
        data_row_length = {'stage': 11, 'gc': 11, 'green': 10, 'youth': 11, 'kom': 10, 'teams': 6}
    data = get_stage_data(stage_html, data_row_length)
    df = build_df(data, result_type)
    return df
    
    
url_uniques = stages_df.url.unique()
count = 0
all_races = list()
print(len(url_uniques))
for uix, url in enumerate(url_uniques):
    
    stage_url = 'https://www.procyclingstats.com/{}'.format(url)
    print('{} in {}: {}'.format(uix, len(url_uniques), stage_url))
    #stage_url = 'https://www.procyclingstats.com/race/tour-de-france/2020/stage-2'
    rdf = get_points(stage_url)
    all_races.append(rdf)
    #if count == 5: break
# Out:
# 190
# 0 in 190: race/tour-de-france/2020/stage-9
# UPDATING 1:stage has 166 participants
# ERROR: ['DNF', '', '+ - 38:40:01', '132', 'rider/fabio-aru', ' Aru Fabio', '30', 'UAE-Team Emirates', '', '', '-']
# ERROR: ['DNF', '', '+ - 38:40:01', '152', 'rider/steff-cras', ' Cras Steff', '24', 'Lotto Soudal', '', '', ',,']
# UPDATING 1:gc has 166 participants
# UPDATING 1:green has 102 participants
# UPDATING 1:youth has 25 participants
# UPDATING 1:kom has 43 participants
# UPDATING 1:teams has 22 participants
# 1 in 190: race/tour-de-france/2020/stage-8
# UPDATING 1:stage has 168 participants
# ERROR: ['DNF', '', '+ - 34:44:52', '191', 'rider/giacomo-nizzolo', ' Nizzolo Giacomo', '31', 'NTT Pro Cycling', '', '', '-']
# ERROR: ['DNF', '', '+ - 34:44:52', '52', 'rider/william-bonnet', ' Bonnet William', '38', 'Groupama - FDJ', '', '', ',,']
# ERROR: ['DNF', '', '+ - 34:44:52', '86', 'rider/diego-rosa', ' Rosa Diego', '31', 'Team Arkéa Samsic', '', '', ',,']
# ERROR: ['DNF', '', '+ - 34:44:52', '183', 'rider/lilian-calmejane', ' Calmejane Lilian', '27', 'Team Total Direct Energie', '', '', ',,']
# UPDATING 1:gc has 168 participants
# UPDATING 1:green has 95 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 36 participants
# UPDATING 1:teams has 22 participants
# 2 in 190: race/tour-de-france/2020/stage-7
# UPDATING 1:stage has 172 participants
# UPDATING 1:gc has 172 participants
# UPDATING 1:green has 89 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 31 participants
# UPDATING 1:teams has 22 participants
# 3 in 190: race/tour-de-france/2020/stage-6
# UPDATING 1:stage has 172 participants
# UPDATING 1:gc has 172 participants
# UPDATING 1:green has 83 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 28 participants
# UPDATING 1:teams has 22 participants
# 4 in 190: race/tour-de-france/2020/stage-5
# UPDATING 1:stage has 172 participants
# UPDATING 1:gc has 172 participants
# UPDATING 1:green has 78 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 23 participants
# UPDATING 1:teams has 22 participants
# 5 in 190: race/tour-de-france/2020/stage-4
# UPDATING 1:stage has 172 participants
# UPDATING 1:gc has 172 participants
# UPDATING 1:green has 72 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 23 participants
# UPDATING 1:teams has 22 participants
# 6 in 190: race/tour-de-france/2020/stage-3
# UPDATING 1:stage has 172 participants
# ERROR: ['DNF', '', '+ - 13:59:17', '126', 'rider/anthony-perez', ' Perez Anthony', '29', 'Cofidis, Solutions Crédits', '', '', '-']
# UPDATING 1:gc has 2 participants
# ERROR: ['-', '204', 'rider/marc-hirschi', ' Hirschi Marc', '22', 'Team Sunweb', '0:07', '..', '4', '5', '▲1']
# UPDATING 1:green has 1 participants
# UPDATING 1:youth has
'', '', ',,']
# ERROR: ['DNF', '', '+ - 22:46:24', '167', 'rider/kevin-reza', ' Reza Kévin', '31', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ERROR: ['DNF', '', '+ - 22:46:24', '96', 'rider/nils-eekhoff', ' Eekhoff Nils', '22', 'Team Sunweb', '', '', ',,']
# ERROR: ['DNF', '', '+ - 22:46:24', '135', 'rider/hugo-hofstetter', ' Hofstetter Hugo', '26', 'Israel Start-Up Nation', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '82', 'rider/pello-bilbao', ' Bilbao Pello', '30', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '136', 'rider/krists-neilands', ' Neilands Krists', '25', 'Israel Start-Up Nation', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '88', 'rider/jan-tratnik', ' Tratnik Jan', '30', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '81', 'rider/dylan-teuns', ' Teuns Dylan', '28', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '132', 'rider/rudy-barbier', ' Barbier Rudy', '27', 'Israel Start-Up Nation', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '71', 'rider/elia-viviani', ' Viviani Elia', '31', 'Cofidis, Solutions Crédits', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '85', 'rider/heinrich-haussler', ' Haussler Heinrich', '36', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '84', 'rider/ivan-garcia-cortina', ' García Cortina Iván', '24', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '66', 'rider/caleb-ewan', ' Ewan Caleb', '25', 'Lotto Soudal', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '86', 'rider/domen-novak', ' Novak Domen', '24', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '83', 'rider/damiano-caruso', ' Caruso Damiano', '32', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '63', 'rider/jasper-de-buyst', 'De Buyst Jasper', '26', 'Lotto Soudal', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '87', 'rider/hermann-pernsteiner', ' Pernsteiner Hermann', '29', 'Bahrain - McLaren', '', '', ',,']
# UPDATING 1:gc has 98 participants
# UPDATING 1:green has 36 participants
# UPDATING 1:youth has 15 participants
# UPDATING 1:kom has 23 participants
# UPDATING 1:teams has 16 participants
# 19 in 190: race/paris-nice/2020/stage-5
# UPDATING 1:stage has 122 participants
# ERROR: ['DNF', '', '+ - 18:49:00', '32', 'rider/pascal-ackermann', ' Ackermann Pascal', '26', 'BORA - hansgrohe', '', '', '-']
# ERROR: ['DNF', '', '+ - 18:49:00', '141', 'rider/julien-el-fares', 'El Fares Julien', '34', 'NIPPO DELKO One Provence', '', '', ',,']
# ERROR: ['DNF', '', '+ - 18:49:00', '17', 'rider/diego-rosa', ' Rosa Diego', '30', 'Team Arkéa Samsic', '', '', ',,']
# ERROR: ['DNF', '', '+ - 18:49:00', '108', 'rider/michael-woods', ' Woods Michael', '33', 'EF Pro Cycling', '', '', ',,']
# ERROR: ['DNF', '', '+ - 18:49:00', '103', 'rider/lawson-craddock', ' Craddock Lawson', '28', 'EF Pro Cycling', '', '', ',,']
# ERROR: ['DNF', '', '+ - 18:49:00', '56', 'rider/oliver-naesen', ' Naesen Oliver', '29', 'AG2R La Mondiale', '', '', ',,']
# ERROR: ['DNF', '', '+ - 18:49:00', '162', 'rider/frederik-backaert', ' Backaert Frederik', '29', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ERROR: ['DNS', '', '+ - 18:49:00', '106', 'rider/tejay-van-garderen', 'van Garderen Tejay', '31', 'EF Pro Cycling', '', '', ',,']
# UPDATING 1:gc has 122 participants
# UPDATING 1:green has 42 participants
# UPDATING 1:youth has 18 participants
# UPDATING 1:kom has 14 participants
# UPDATING 1:teams has 17 participants
# 20 in 190: race/paris-nice/2020/stage-4
# (ITT)
# UPDATING 1:stage has 130 participants
# UPDATING 1:gc has 0 participants
# 21 in 190: race/paris-nice/2020/stage-3
# UPDATING 1:stage has 133 participants
# UPDATING 1:gc has 133 participants
# UPDATING 1:green has 29 participants
# UPDATING 1:youth has 18 participants
# UPDATING 1:kom has 10 participants
# UPDATING 1:teams has 17 participants
# 22 in 190: race/paris-nice/2020/stage-2
# UPDATING 1:stage has 133 participants
# UPDATING 1:gc has 1 participants
# UPDATING 1:green has 1 participants
# UPDATING 1:youth has 1 participants
# ERROR: ['▲6', '101', 'rider/sergio-higuita', ' Higuita Sergio', '22', 'EF Pro Cycling', '0:23', '..', '5', '8', '▲3']
# UPDATING 1:kom has 1 participants
# UPDATING 1:teams has 1 participants
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-307-50d1ce3ce1e2> in <module>
#      32     stage_url = 'https://www.procyclingstats.com/{}'.format(url)
#      33     #stage_url = 'https://www.procyclingstats.com/race/tour-de-france/2020/stage-2'
# ---> 34     rdf = get_points(stage_url)
#      35     all_races.append(rdf)
#      36     #if count == 5: break
#
# <ipython-input-307-50d1ce3ce1e2> in get_points(url)
#      19         result_type = OTHER_TOUR_STAGE
#      20         data_row_length = {'stage': 11, 'gc': 11, 'green': 10, 'youth': 11, 'kom': 10, 'teams': 6}
# ---> 21     data = get_stage_data(stage_html, data_row_length)
#      22     df = build_df(data, result_type)
#      23     return df
#
# <ipython-input-297-2a04bfe31889> in get_stage_data(html, data_row_length)
#      62                 last_ix = 1
#      63                 try:
# ---> 64                     row_length = data_row_length[datasets[data_id]]
#      65                 except KeyError:
#      66                     break
#
# IndexError: list index out of range

# %%
# remove the race headings
print(riders_df.shape)
riders_df = riders_df[(riders_df.distance != '') & (riders_df.gc_pos != '')]
riders_df.drop(['uci'], axis = 1, inplace=True)
print(riders_df.shape)
riders_df.head(10)
# Out:
# (5462, 9)
# (3492, 8)
#      date  pos gc_pos                                           stage  \
# 1   04.09  152    142                      Stage 7 - Millau › Lavaur
# 2   03.09  147    139               Stage 6 - Le Teil › Mont Aigoual
# 3   02.09   14    135                         Stage 5 - Gap › Privas
# 4   01.09  158    138         Stage 4 - Sisteron › Orcières-Merlette
# 5   31.08   15    127                      Stage 3 - Nice › Sisteron
# 6   30.08  137    129                          Stage 2 - Nice › Nice
# 7   29.08    1      1                          Stage 1 - Nice › Nice
# 12  15.08  138    135                       Stage 4 - Ugine › Megève
# 13  14.08  151    144  Stage 3 - Corenc › Saint-Martin-de-Belleville
# 14  13.08  135    142                Stage 2 - Vienne › Col de Porte
#
#    distance  pcs                rider  race_id
# 1       168        kristoff alexander        0
# 2       191        kristoff alexander        0
# 3       183    2   kristoff alexander        0
# 4     160.5        kristoff alexander        0
# 5       198    1   kristoff alexander        0
# 6       186        kristoff alexander        0
# 7       156  100   kristoff alexander        0
# 12    148.5        kristoff alexander        1
# 13      157        kristoff alexander        1
# 14      135        kristoff alexander        1

# %%
#DNF=Did not finish / DNS=Did not start / OTL = Outside time limit / DF
riders_df[riders_df.pos =='DF']
# Out:
# Empty DataFrame
# Columns: [date, pos, gc_pos, stage, distance, rider, race_id]
# Index: []

# %%
#result.groupby(['race', 'stage']).count()[['pos']]
#all_df['rc'] = np.where(all_df['distance']=='', all_df['race'], '')
