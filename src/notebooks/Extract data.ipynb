# %% [markdown]
# # Extract data
# The aim of this notebook is to extract professional cyclists' data for a season. Cleaning of the data will be done as well. Feature creation and analysis will be done on the next notebook.
#
# We extract all the riders at the beginning of the tour. Thereafter we itterate through each rider's profile on `procyclingstats.com` and scrape the races that they have partaken in, for the season. Thereafter, we itterate through all the races and extract their profiles (diificulty, uci status). The data is saved.

# %%
# imports
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
RACE = 'tour-de-france'
YEAR = 2020
STAGE = 1
URL1 = 'https://www.procyclingstats.com/race/{}/{}/stage-{}/result/result'.format(RACE, YEAR, STAGE)
race_page = requests.get(URL1)
race_html = BeautifulSoup(race_page.content, 'html.parser')

# %%
class DataObject:
    def __init__(self, name, row_length):
        self.data = None
        self.data_added = False
        self.row_length = 0
        self.data_name = None

    def add_data(self, data):
        self.data = data
        self.data_added = True

# %%
def is_not_int(value):
    try:
        int(value)
        return False
    except ValueError:
        return True

def get_text(cell):
    ''' Return the text from the html cell. '''
    # some cells have a span or hyperlink element with text in it
    if cell.a != None:
        url = cell.a.get('href')
        if url.startswith('rider/') or url.startswith('race/'):
            return url, cell.a.get_text()
        return cell.a.get_text()
    elif cell.span != None:
        return cell.span.get_text()
    else:
        return cell.get_text()
    
def get_stage_data(html, data_row_length, print_row=False):
    # all the racers are in a table data cell ('td')
    row_cells = html.find_all('td')
    data = {'stage': list(), 'gc': list(), 'green': list(), 'youth': list(), 'kom': list(), 'teams': list()}
    datasets = list(data.keys())
    data_id = 0
    row_length = data_row_length[datasets[data_id]]
    old_length = row_length
    data_obj = DataObject(datasets[data_id], row_length)
    
    temp_list = list()
    error_list = list()
    error_row = False
    #print(data, datasets, data_id, datasets[data_id])
    
    row = list()
    last_ix = 1

    # itterate through all data cells and append their text values to a row
    for row_ix, cell in enumerate(row_cells):
        
        #if datasets[data_id] in ['kom', 'teams']:
        #    print('{} of {}'.format(row_ix, len(row_cells)))
        
        text = get_text(cell)
        if type(text) is type('str'):
            row.append(text)
        else:
            row.append(text[0])
            row.append(text[1])
            
        if len(row) == 1:
            not_int = is_not_int(row[0])
            if (not_int or int(row[0]) != last_ix) and len(temp_list) != 0:
                print('UPDATING 1:{} has {} participants'.format(datasets[data_id], len(temp_list)))
                ds = datasets[data_id]
                data[ds] = temp_list
                data_id += 1
                old_length = row_length
                
                temp_list = list()
                last_ix = 1
                try:
                    row_length = data_row_length[datasets[data_id]]
                except KeyError:
                    break
            
            if not_int:
                error_row = True
                
        if error_row:
            if len(row) == old_length:
                print('ERROR: {}'.format(row))
                error_list.append(row)
                error_row = False
                row = list()
        else:
            # 'row_length' data cells make an entire row
            if len(row) == row_length:
                if print_row:
                    print(row)
                # data list gets saved in data subset
                pos = int(row[0])
                temp_list.append(row)
                last_ix = pos + 1
                row = list()
                
    print('UPDATING 1:{} has {} participants'.format(datasets[data_id], len(temp_list)))
    ds = datasets[data_id]
    data[ds] = temp_list
    return data

data_row_length = {'stage': 11, 'gc': 9, 'green': 8, 'youth': 9, 'kom': 8, 'teams': 4}
data = get_stage_data(race_html, data_row_length)
#data.get('stage')
# Out:
# UPDATING 1:stage has 175 participants
# ERROR: ['OTL', '', '+ -3:46:13', '155', 'rider/john-degenkolb', ' Degenkolb John', '31', 'Lotto Soudal', '', '', '-']
# UPDATING 1:gc has 175 participants
# UPDATING 1:green has 24 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 3 participants
# UPDATING 1:teams has 22 participants

# %%
#def make_dfs(data):
#    
#    df = pd.DataFrame(data, columns=['stagePos', 'gcPos', 'timeAdd', 'bib', 'url', 'name', \
#                          'age', 'team', 'uci','pnt', 'time'])

#df = pd.DataFrame(data['stage'], columns=['stagePos', 'gcPos', 'timeAdd', 'bib', 'url', 'name', 'age', 'team', 'uci','pnt', 'time'])
#df = pd.DataFrame(data['gc'], columns=['gcPos', 'bib', 'url', 'name', 'age', 'team', 'uci', 'time', 'more'])
#df = pd.DataFrame(data['green'], columns=['greenPos', 'bib', 'url', 'name', 'age', 'team', 'pnts', 'pnts_chng'])
#df = pd.DataFrame(data['youth'], columns=['youthPos', 'gcPos', 'timeAdd', 'bib', 'url', 'name', 'age', 'team', 'youthTime'])
#df = pd.DataFrame(data['kom'], columns=['komPos', 'bib', 'url', 'name', 'age', 'team', 'pnts',  'pnts_chng'])
#df = pd.DataFrame(data['teams'], columns=['teamPos', 'change', 'name', 'time'])
df.head()
# Out:
#   teamPos change                         name       time
# 0       1                   Trek - Segafredo    11:19:09
# 1       2                  UAE-Team Emirates          ,,
# 2       3         Cofidis, Solutions Crédits          ,,
# 3       4                        Team Sunweb          ,,
# 4       5            Deceuninck - Quick Step          ,,

# %%
# make the dataframe
df = pd.DataFrame(data, columns=['stagePos', 'gcPos', 'timeAdd', 'bib', 'url', 'name', \
                          'age', 'team', 'uci','pnt', 'time'])
df.name = df.name.str.upper()
df.team = df.team.str.upper()
# data erroneoulsy added to df
cutoff_ix = df[df.gcPos == ''].index[0]

first_df = df.loc[:cutoff_ix-1, :]
print('There were {} cyclists that finished stage 1'.format(first_df.shape[0]))
first_df.head()
# Out:
# There were 175 cyclists that finished stage 1
#   stagePos gcPos timeAdd  bib                       url                 name  \
# 0        1     1   +0:00  135  rider/alexander-kristoff   KRISTOFF ALEXANDER
# 1        2     2   +0:04  105       rider/mads-pedersen        PEDERSEN MADS
# 2        3     3   +0:06  203            rider/cees-bol             BOL CEES
# 3        4     4   +0:10   43         rider/sam-bennett          BENNETT SAM
# 4        5     5   +0:10   21         rider/peter-sagan          SAGAN PETER
#
#   age                     team  uci  pnt     time
# 0  33        UAE-TEAM EMIRATES  120  100  3:46:23
# 1  24         TREK - SEGAFREDO   50   70       ,,
# 2  25              TEAM SUNWEB   25   50       ,,
# 3  29  DECEUNINCK - QUICK STEP   15   40       ,,
# 4  30         BORA - HANSGROHE    5   32       ,,

# %% [markdown]
# ## Create dataframes
# We are going to separate the data frame above into 3 more succinct dataframes.
#
# - `riders_df` that contians the 175 riders' personal infomration.
# - `stages_df` that containes that stages competed in by all the 175 riders in the past season
# - `races_df` that contains the information about the races that the 175 riders competed in in the past season (a race can have multiple stages)

# %%
riders_df = first_df[['name', 'age', 'url', 'team']]
riders_df = riders_df.sort_values('name')
riders_df['riderID'] = range(riders_df.shape[0])
riders_df = riders_df.set_index('riderID')
riders_df.head()
# Out:
#                         name age                       url  \
# riderID
# 0         ALAPHILIPPE JULIAN  28  rider/julian-alaphilippe
# 1              AMADOR ANDREY  34       rider/andrey-amador
# 2             ANACONA WINNER  32      rider/winner-anacona
# 3               ARNDT NIKIAS  28        rider/nikias-arndt
# 4                  ARU FABIO  30           rider/fabio-aru
#
#                             team
# riderID
# 0        DECEUNINCK - QUICK STEP
# 1               INEOS GRENADIERS
# 2              TEAM ARKÉA SAMSIC
# 3                    TEAM SUNWEB
# 4              UAE-TEAM EMIRATES

# %%
def find_races(url, rider_id, rider_name):
    ''' Extract all the races in the season for the rider on the rider's profile (url)'''
    page = requests.get(url)
    rider_html = BeautifulSoup(page.content, 'html.parser')
    results_html = rider_html.body.tbody
    # all races in data rows
    rows = results_html.find_all('tr')

    races = list()
    for row in rows:
        items = row.find_all('td')
        # extract text values from data cell
        row = list()
        for item in items:
            text = get_text(item)
            if type(text) is type('str'):
                row.append(text)
            else:
                row.append(text[0])
                row.append(text[1])
        races.append(row)
    df = pd.DataFrame(races, columns=['date', 'stagePos', 'gcPos', 'unknown', 'url', 'stage', 'distance', 'pcs', 'uci', 'more'])
    print('"{}" competed in {} stages'.format(rider_name, df.shape[0]))
    df['riderID'] = rider_id
    return df

# initialise list of dataframes
stages_list = list()
# itterate through each cyclist and add his races for the season
# to a list of dataframes
for ix, row in riders_df.iterrows():
    print('{} of {}'.format(ix, riders_df.shape[0]))
    url = row['url']
    name = row['name']
    rider_url = 'https://www.procyclingstats.com/{}'.format(url)
    rider_df = find_races(rider_url, ix, name)
    stages_list.append(rider_df)
# Out:
# 0 of 175
# " ALAPHILIPPE JULIAN" competed in 48 stages
# 1 of 175
# " AMADOR ANDREY" competed in 30 stages
# 2 of 175
# " ANACONA WINNER" competed in 46 stages
# 3 of 175
# " ARNDT NIKIAS" competed in 37 stages
# 4 of 175
# " ARU FABIO" competed in 36 stages
# 5 of 175
# " ASGREEN KASPER" competed in 45 stages
# 6 of 175
# " BARDET ROMAIN" competed in 53 stages
# 7 of 175
# " BARGUIL WARREN" competed in 38 stages
# 8 of 175
# " BARTHE CYRIL" competed in 53 stages
# 9 of 175
# " BAUER JACK" competed in 34 stages
# 10 of 175
# " BENNETT GEORGE" competed in 40 stages
# 11 of 175
# " BENNETT SAM" competed in 51 stages
# 12 of 175
# " BENOOT TIESJ" competed in 29 stages
# 13 of 175
# " BERNAL EGAN" competed in 44 stages
# 14 of 175
# " BETTIOL ALBERTO" competed in 33 stages
# 15 of 175
# " BEWLEY SAM" competed in 31 stages
# 16 of 175
# " BILBAO PELLO" competed in 51 stages
# 17 of 175
# " BOASSON HAGEN EDVALD" competed in 36 stages
# 18 of 175
# " BOL CEES" competed in 31 stages
# 19 of 175
# " BONIFAZIO NICCOLÒ" competed in 38 stages
# 20 of 175
# " BONNET WILLIAM" competed in 14 stages
# 21 of 175
# " BUCHMANN EMANUEL" competed in 23 stages
# 22 of 175
# " BURGAUDEAU MATHIEU" competed in 35 stages
# 23 of 175
# " CALMEJANE LILIAN" competed in 47 stages
# 24 of 175
# " CARAPAZ RICHARD" competed in 37 stages
# 25 of 175
# " CARTHY HUGH" competed in 25 stages
# 26 of 175
# " CARUSO DAMIANO" competed in 43 stages
# 27 of 175
# " CASTROVIEJO JONATHAN" competed in 38 stages
# 28 of 175
# " CATALDO DARIO" competed in 32 stages
# 29 of 175
# " CAVAGNA RÉMI" competed in 48 stages
# 30 of 175
# " CHAVES ESTEBAN" competed in 39 stages
# 31 of 175
# " CHEREL MIKAËL" competed in 46 stages
# 32 of 175
# " CHEVALIER MAXIME" competed in 25 stages
# 33 of 175
# " COLBRELLI SONNY" competed in 36 stages
# 34 of 175
# " CONSONNI SIMONE" competed in 35 stages
# 35 of 175
# " COQUARD BRYAN" competed in 43 stages
# 36 of 175
# " COSNEFROY BENOÎT" competed in 53 stages
# 37 of 175
# " COUSIN JÉRÔME" competed in 40 stages
# 38 of 175
# " CRAS STEFF" competed in 26 stages
# 39 of 175
# " DEBUSSCHERE JENS" competed in 47 stages
# 40 of 175
# " DECLERCQ TIM" competed in 47 stages
# 41 of 175
# " DEVENYNS DRIES" competed in 37 stages
# 42 of 175
# " DUMOULIN TOM" competed in 25 stages
# 43 of 175
# " EDET NICOLAS" competed in 53 stages
# 44 of 175
# " EG NIKLAS" competed in 44 stages
# 45 of 175
# " ELISSONDE KENNY" competed in 50 stages
# 46 of 175
# " ERVITI IMANOL" competed in 24 stages
# 47 of 175
# " EWAN CALEB" competed in 45 stages
# 48 of 175
# " FORMOLO DAVIDE" competed in 30 stages
# 49 of 175
# " FRAILE OMAR" competed in 45 stages
# 50 of 175
# " FRISON FREDERIK" competed in 44 stages
# 51 of 175
# " GAUDU DAVID" competed in 45 stages
# 52 of 175
# " GAUTIER CYRIL" competed in 46 stages
# 53 of 175
# " GESCHKE SIMON" competed in 40 stages
# 54 of 175
# " GESINK ROBERT" competed in 29 stages
# 55 of 175
# " GIBBONS RYAN" competed in 44 stages
# 56 of 175
# " GILBERT PHILIPPE" competed in 37 stages
# 57 of 175
# " GOGL MICHAEL" competed in 45 stages
# 58 of 175
# " GREIPEL ANDRÉ" competed in 31 stages
# 59 of 175
# " GRELLIER FABIEN" competed in 41 stages
# 60 of 175
# " GROSSSCHARTNER FELIX" competed in 52 stages
# 61 of 175
# " HALLER MARCO" competed in 44 stages
# 62 of 175
# " HERMANS BEN" competed in 25 stages
# 63 of 175
# " HERRADA JESÚS" competed in 35 stages
# 64 of 175
# " HIGUITA SERGIO" competed in 43 stages
# 65 of 175
# " HIRSCHI MARC" competed in 32 stages
# 66 of 175
# " HIRT JAN" competed in 32 stages
# 67 of 175
# " HOFSTETTER HUGO" competed in 47 stages
# 68 of 175
# " HOULE HUGO" competed in 36 stages
# 69 of 175
# " IMPEY DARYL" competed in 39 stages
# 70 of 175
# " IZAGIRRE GORKA" competed in 37 stages
# 71 of 175
# " IZAGIRRE ION" competed in 38 stages
# 72 of 175
# " JANSEN AMUND GRØNDAHL" competed in 14 stages
# 73 of 175
# " JUNGELS BOB" competed in 42 stages
# 74 of 175
# " JUUL-JENSEN CHRISTOPHER" competed in 32 stages
# 75 of 175
# " KEUKELEIRE JENS" competed in 29 stages
# 76 of 175
# " KLUGE ROGER" competed in 48 stages
# 77 of 175
# " KOCH JONAS" competed in 39 stages
# 78 of 175
# " KREUZIGER ROMAN" competed in 42 stages
# 79 of 175
# " KRISTOFF ALEXANDER" competed in 39 stages
# 80 of 175
# " KUSS SEPP" competed in 35 stages
# 81 of 175
# " KWIATKOWSKI MICHAŁ" competed in 33 stages
# 82 of 175
# " KÄMNA LENNARD" competed in 48 stages
# 83 of 175
# " KÜNG STEFAN" competed in 41 stages
# 84 of 175
# " LADAGNOUS MATTHIEU" competed in 45 stages
# 85 of 175
# " LAENGEN VEGARD STAKE" competed in 42 stages
# 86 of 175
# " LANDA MIKEL" competed in 38 stages
# 87 of 175
# " LAPORTE CHRISTOPHE" competed in 22 stages
# 88 of 175
# " LATOUR PIERRE" competed in 44 stages
# 89 of 175
# " LEDANOIS KÉVIN" competed in 36 stages
# 90 of 175
# " LUTSENKO ALEXEY" competed in 38 stages
# 91 of 175
# " LÓPEZ MIGUEL ÁNGEL" competed in 35 stages
# 92 of 175
# " MADOUAS VALENTIN" competed in 37 stages
# 93 of 175
# " MARCATO MARCO" competed in 37 stages
# 94 of 175
# " MARTIN DAN" competed in 38 stages
# 95 of 175
# " MARTIN GUILLAUME" competed in 51 stages
# 96 of 175
# " MARTIN TONY" competed in 28 stages
# 97 of 175
# " MARTÍNEZ DANIEL FELIPE" competed in 33 stages
# 98 of 175
# " MAS ENRIC" competed in 40 stages
# 99 of 175
# " MEZGEC LUKA" competed in 37 stages
# 100 of 175
# " MOHORIČ MATEJ" competed in 38 stages
# 101 of 175
# " MOLARD RUDY" competed in 42 stages
# 102 of 175
# " MOLLEMA BAUKE" competed in 36 stages
# 103 of 175
# " MØRKØV MICHAEL" competed in 51 stages
# 104 of 175
# " MÜHLBERGER GREGOR" competed in 36 stages
# 105 of 175
# " NAESEN OLIVER" competed in 43 stages
# 106 of 175
# " NEILANDS KRISTS" competed in 33 stages
# 107 of 175
# " NIEUWENHUIS JORIS" competed in 16 stages
# 108 of 175
# " NIEVE MIKEL" competed in 36 stages
# 109 of 175
# " NIV GUY" competed in 32 stages
# 110 of 175
# " NIZZOLO GIACOMO" competed in 51 stages
# 111 of 175
# " OLIVEIRA NELSON" competed in 39 stages
# 112 of 175
# " OSS DANIEL" competed in 30 stages
# 113 of 175
# " PACHER QUENTIN" competed in 46 stages
# 114 of 175
# " PEDERSEN CASPER" competed in 28 stages
# 115 of 175
# " PEDERSEN MADS" competed in 47 stages
# 116 of 175
# " PEREZ ANTHONY" competed in 41 stages
# 117 of 175
# " PETERS NANS" competed in 46 stages
# 118 of 175
# " PINOT THIBAUT" competed in 52 stages
# 119 of 175
# " POELS WOUT" competed in 33 stages
# 120 of 175
# " POGAČAR TADEJ" competed in 43 stages
# 121 of 175
# " POLANC JAN" competed in 37 stages
# 122 of 175
# " POLITT NILS" competed in 42 stages
# 123 of 175
# " PORTE RICHIE" competed in 62 stages
# 124 of 175
# " POWLESS NEILSON" competed in 37 stages
# 125 of 175
# " POZZOVIVO DOMENICO" competed in 30 stages
# 126 of 175
# " PÉRICHON PIERRE-LUC" competed in 40 stages
# 127 of 175
# " PÖSTLBERGER LUKAS" competed in 37 stages
# 128 of 175
# " QUINTANA DAYER" competed in 39 stages
# 129 of 175
# " QUINTANA NAIRO" competed in 51 stages
# 130 of 175
# " REICHENBACH SÉBASTIEN" competed in 32 stages
# 131 of 175
# " REZA KÉVIN" competed in 45 stages
# 132 of 175
# " ROCHE NICOLAS" competed in 24 stages
# 133 of 175
# " ROGLIČ PRIMOŽ" competed in 25 stages
# 134 of 175
# " ROJAS JOSÉ JOAQUÍN" competed in 36 stages
# 135 of 175
# " ROLLAND PIERRE" competed in 41 stages
# 136 of 175
# " ROSA DIEGO" competed in 39 stages
# 137 of 175
# " ROWE LUKE" competed in 45 stages
# 138 of 175
# " RUSSO CLÉMENT" competed in 34 stages
# 139 of 175
# " SAGAN PETER" competed in 36 stages
# 140 of 175
# " SCHACHMANN MAXIMILIAN" competed in 40 stages
# 141 of 175
# " SCHÄR MICHAEL" competed in 39 stages
# 142 of 175
# " SICARD ROMAIN" competed in 41 stages
# 143 of 175
# " SIVAKOV PAVEL" competed in 49 stages
# 144 of 175
# " SKUJIŅŠ TOMS" competed in 29 stages
# 145 of 175
# " SOLER MARC" competed in 44 stages
# 146 of 175
# " SOUPE GEOFFREY" competed in 39 stages
# 147 of 175
# " STUYVEN JASPER" competed in 49 stages
# 148 of 175
# " SWIFT CONNOR" competed in 50 stages
# 149 of 175
# " SÁNCHEZ LUIS LEÓN" competed in 55 stages
# 150 of 175
# " TEJADA HAROLD" competed in 30 stages
# 151 of 175
# " THEUNS EDWARD" competed in 46 stages
# 152 of 175
# " TRENTIN MATTEO" competed in 51 stages
# 153 of 175
# " TURGIS ANTHONY" competed in 49 stages
# 154 of 175
# " URÁN RIGOBERTO" competed in 25 stages
# 155 of 175
# " VALGREN MICHAEL" competed in 44 stages
# 156 of 175
# " VALLS RAFAEL" competed in 29 stages
# 157 of 175
# " VALVERDE ALEJANDRO" competed in 53 stages
# 158 of 175
# " VENTURINI CLÉMENT" competed in 46 stages
# 159 of 175
# " VERONA CARLOS" competed in 32 stages
# 160 of 175
# " VIVIANI ELIA" competed in 46 stages
# 161 of 175
# " VUILLERMOZ ALEXIS" competed in 23 stages
# 162 of 175
# " WALSCHEID MAX" competed in 50 stages
# 163 of 175
# " YATES ADAM" competed in 25 stages
# 164 of 175
# " ZAKARIN ILNUR" competed in 25 stages
# 165 of 175
# "DE BUYST JASPER" competed in 35 stages
# 166 of 175
# "DE GENDT THOMAS" competed in 48 stages
# 167 of 175
# "DE LA CRUZ DAVID" competed in 41 stages
# 168 of 175
# "DE MARCHI ALESSANDRO" competed in 26 stages
# 169 of 175
# "KRAGH ANDERSEN SØREN" competed in 34 stages
# 170 of 175
# "VAN AERT WOUT" competed in 24 stages
# 171 of 175
# "VAN ASBROECK TOM" competed in 44 stages
# 172 of 175
# "VAN AVERMAET GREG" competed in 40 stages
# 173 of 175
# "VAN BAARLE DYLAN" competed in 41 stages
# 174 of 175
# "VAN GARDEREN TEJAY" competed in 31 stages

# %%
stages_ = pd.concat(stages_list).reset_index(drop=True)
print('{} stages have been loaded'.format(stages_.shape[0]))
# drop 2 unnecessary columns
stages_ = stages_.drop(['unknown', 'more'], axis=1)
stages_.head()
# Out:
# 6765 stages have been loaded
#        date stagePos gcPos                               url  \
# 0   › 20.09                 race/tour-de-france/2020/stage-1
# 1     06.09      160    38  race/tour-de-france/2020/stage-9
# 2     05.09       38    26  race/tour-de-france/2020/stage-8
# 3     04.09       12    11  race/tour-de-france/2020/stage-7
# 4     03.09        5    16  race/tour-de-france/2020/stage-6
#
#                               stage distance pcs uci  riderID
# 0                    Tour de France                         0
# 1            Stage 9 - Pau › Laruns      153                0
# 2  Stage 8 - Cazères › Loudenvielle      141                0
# 3         Stage 7 - Millau › Lavaur      168   6            0
# 4  Stage 6 - Le Teil › Mont Aigoual      191  32   5        0

# %%
# TODO: Test this
# TODO: take points classifications. make columns for them . Add them to race information
#to_drop = stages_[(stages_.date == '') & (stages_.gcPos == '')]
#print(to_drop.shape)
#to_drop.head(20)
# jersey and points classification have no date or gc position
#all_ = all_[(all_.date != '') | (all_.gc_pos != '')]
#print(all_.shape)
#all_.head()

# %%
races_df = stages_[(stages_.distance == '') & (stages_.stagePos == '')][['stage', 'url']]
races_df.head()
# TODO: Does this still work?
races_df.columns = ['race', 'url']
#races_df['uci_rank'] = races_df.uci_rank.str.replace(')', '')
races_df['raceID'] = range(races_df.shape[0])
races_df.head()
# TODO: Access race html and see if you can get more info about race
# TODO: stage_df?
# Out:
#                                race  \
# 0                    Tour de France
# 11            Critérium du Dauphiné
# 22                     Paris - Nice
# 35                Tour Colombia 2.1
# 44  Vuelta a San Juan Internacional
#
#                                                   url  raceID
# 0                    race/tour-de-france/2020/stage-1       0
# 11                         race/dauphine/2020/stage-1       1
# 22                       race/paris-nice/2020/stage-1       2
# 35                      race/colombia-21/2020/stage-1       3
# 44  race/vuelta-ciclista-a-la-provincia-de-san-jua...       4

# %%
# add race id
stages_df = pd.concat([stages_, races_df['raceID']], axis=1, sort=False)
stages_df['raceID'] = stages_df['raceID'].fillna(method='ffill').astype(int)
print(stages_df.shape)
# drop the races & classifications from stages
stages_df = stages_df[(stages_df.stagePos != '') | (stages_df.distance != '')]
stages_df = stages_df[(stages_df.date != '')]
print(stages_df.shape)

stages_df.head()
# Out:
# (6765, 10)
# (5022, 10)
#     date stagePos gcPos                               url  \
# 1  06.09      160    38  race/tour-de-france/2020/stage-9
# 2  05.09       38    26  race/tour-de-france/2020/stage-8
# 3  04.09       12    11  race/tour-de-france/2020/stage-7
# 4  03.09        5    16  race/tour-de-france/2020/stage-6
# 5  02.09       16    16  race/tour-de-france/2020/stage-5
#
#                               stage distance pcs uci  riderID  raceID
# 1            Stage 9 - Pau › Laruns      153                0       0
# 2  Stage 8 - Cazères › Loudenvielle      141                0       0
# 3         Stage 7 - Millau › Lavaur      168   6            0       0
# 4  Stage 6 - Le Teil › Mont Aigoual      191  32   5        0       0
# 5            Stage 5 - Gap › Privas      183                0       0

# %%
stage_url = 'https://www.procyclingstats.com/race/tour-de-france/2020/stage-3'
page = requests.get(stage_url)
stage_html = BeautifulSoup(page.content, 'html.parser')
print('(ITT)' in str(stage_html.h2), str(stage_html.h2))

data_row_length = data_row_length = {'stage': 11, 'gc': 11, 'green': 10, 'youth': 11, 'kom': 10, 'teams': 6}
data = get_stage_data(stage_html, data_row_length, True)
# Out:
# False <h2><span class="yearmob hide">2020  </span><span class="blue">Stage 3</span>  »  <span class="red">Nice  ›  Sisteron  </span> <span class="red distance">(198k)</span></h2>
# ['1', '153', '+29:13', '151', 'rider/caleb-ewan', ' Ewan Caleb', '26', 'Lotto Soudal', '120', '100', '5:17:42']
# ['2', '142', '+29:04', '43', 'rider/sam-bennett', ' Bennett Sam', '29', 'Deceuninck - Quick Step', '50', '70', ',,']
# ['3', '143', '+29:06', '191', 'rider/giacomo-nizzolo', ' Nizzolo Giacomo', '31', 'NTT Pro Cycling', '25', '50', ',,']
# ['4', '133', '+28:30', '174', 'rider/hugo-hofstetter', ' Hofstetter Hugo', '26', 'Israel Start-Up Nation', '15', '40', ',,']
# ['5', '81', '+18:00', '21', 'rider/peter-sagan', ' Sagan Peter', '30', 'BORA - hansgrohe', '5', '32', ',,']
# ['6', '83', '+18:00', '108', 'rider/edward-theuns', ' Theuns Edward', '29', 'Trek - Segafredo', '', '26', ',,']
# ['7', '144', '+29:06', '203', 'rider/cees-bol', ' Bol Cees', '25', 'Team Sunweb', '', '22', ',,']
# ['8', '107', '+20:57', '117', 'rider/matteo-trentin', ' Trentin Matteo', '31', 'CCC Team', '', '18', ',,']
# ['9', '145', '+29:10', '211', 'rider/bryan-coquard', ' Coquard Bryan', '28', 'B&B Hotels - Vital Concept p/b KTM', '', '14', ',,']
# ['10', '167', '+40:14', '181', 'rider/niccolo-bonifazio', ' Bonifazio Niccolò', '26', 'Team Total Direct Energie', '', '10', ',,']
# ['11', '129', '+28:30', '167', 'rider/luka-mezgec', ' Mezgec Luka', '32', 'Mitchelton-Scott', '', '8', ',,']
# ['12', '116', '+21:53', '178', 'rider/tom-van-asbroeck', 'Van Asbroeck Tom', '30', 'Israel Start-Up Nation', '', '6', ',,']
# ['13', '82', '+18:00', '115', 'rider/jonas-koch', ' Koch Jonas', '27', 'CCC Team', '', '4', ',,']
# ['14', '108', '+20:57', '162', 'rider/jack-bauer', ' Bauer Jack', '35', 'Mitchelton-Scott', '', '2', ',,']
# ['15', '127', '+28:20', '135', 'rider/alexander-kristoff', ' Kristoff Alexander', '33', 'UAE-Team Emirates', '', '1', ',,']
# ['16', '115', '+21:53', '143', 'rider/hugo-houle', ' Houle Hugo', '29', 'Astana Pro Team', '', '', ',,']
# ['17', '37', '+1:27', '97', 'rider/marc-soler', ' Soler Marc', '26', 'Movistar Team', '', '', ',,']
# ['18', '13', '+0:17', '146', 'rider/aleksey-lutsenko', ' Lutsenko Alexey', '27', 'Astana Pro Team', '', '', ',,']
# ['19', '55', '+5:50', '107', 'rider/jasper-stuyven', ' Stuyven Jasper', '28', 'Trek - Segafredo', '', '', ',,']
# ['20', '146', '+29:10', '122', 'rider/simone-consonni', ' Consonni Simone', '25', 'Cofidis, Solutions Crédits', '', '', ',,']
# ['21', '24', '+0:17', '63', 'rider/damiano-caruso', ' Caruso Damiano', '32', 'Bahrain - McLaren', '', '', ',,']
# ['22', '4', '+0:17', '131', 'rider/tadej-pogacar', ' Pogačar Tadej', '21', 'UAE-Team Emirates', '', '', ',,']
# ['23', '65', '+10:12', '138', 'rider/jan-polanc', ' Polanc Jan', '28', 'UAE-Team Emirates', '', '', ',,']
# ['24', '74', '+12:58', '37', 'rider/clement-venturini', ' Venturini Clément', '26', 'AG2R La Mondiale', '', '', ',,']
# ['25', '80', '+18:00', '35', 'rider/oliver-naesen', ' Naesen Oliver', '29', 'AG2R La Mondiale', '', '', ',,']
# ['26', '147', '+29:10', '87', 'rider/clement-russo', ' Russo Clément', '25', 'Team Arkéa Samsic', '', '', ',,']
# ['27', '85', '+18:00', '26', 'rider/daniel-oss', ' Oss Daniel', '33', 'BORA - hansgrohe', '', '', ',,']
# ['28', '90', '+18:00', '142', 'rider/omar-fraile', ' Fraile Omar', '30', 'Astana Pro Team', '', '', ',,']
# ['29', '9', '+0:17', '121', 'rider/guillaume-martin', ' Martin Guillaume', '27', 'Cofidis, Solutions Crédits', '', '', ',,']
# ['30', '5', '+0:17', '134', 'rider/davide-formolo', ' Formolo Davide', '27', 'UAE-Team Emirates', '', '', ',,']
# ['31', '67', '+10:34', '25', 'rider/gregor-muhlberger', ' Mühlberger Gregor', '26', 'BORA - hansgrohe', '', '', ',,']
# ['32', '132', '+28:30', '48', 'rider/michael-morkov', ' Mørkøv Michael', '35', 'Deceuninck - Quick Step', '', '', ',,']
# ['33', '130', '+28:30', '128', 'rider/elia-viviani', ' Viviani Elia', '31', 'Cofidis, Solutions Crédits', '', '', ',,']
# ['34', '7', '+0:17', '14', 'rider/tom-dumoulin', ' Dumoulin Tom', '29', 'Team Jumbo-Visma', '', '', ',,']
# ['35', '128', '+28:24', '105', 'rider/mads-pedersen', ' Pedersen Mads', '24', 'Trek - Segafredo', '', '', ',,']
# ['36', '6', '+0:17', '1', 'rider/egan-bernal', ' Bernal Egan', '23', 'INEOS Grenadiers', '', '', ',,']
# ['37', '168', '+40:14', '202', 'rider/nikias-arndt', ' Arndt Nikias', '28', 'Team Sunweb', '', '', ',,']
# ['38', '19', '+0:17', '147', 'rider/luis-leon-sanchez', ' Sánchez Luis León', '36', 'Astana Pro Team', '', '', ',,']
# ['39', '131', '+28:30', '188', 'rider/anthony-turgis', ' Turgis Anthony', '26', 'Team Total Direct Energie', '', '', ',,']
# ['40', '165', '+34:01', '84', 'rider/kevin-ledanois', ' Ledanois Kévin', '27', 'Team Arkéa Samsic', '', '', ',,']
# ['41', '2', '+0:04', '161', 'rider/adam-yates', ' Yates Adam', '28', 'Mitchelton-Scott', '', '', ',,']
# ['42', '21', '+0:17', '141', 'rider/miguel-angel-lopez', ' López Miguel Ángel', '26', 'Astana Pro Team', '', '', ',,']
# ['43', '134', '+28:30', '125', 'rider/christophe-laporte', ' Laporte Christophe', '27', 'Cofidis, Solutions Crédits', '', '', ',,']
# ['44', '119', '+21:53', '93', 'rider/imanol-erviti', ' Erviti Imanol', '36', 'Movistar Team', '', '', ',,']
# ['45', '86', '+18:00', '201', 'rider/tiesj-benoot', ' Benoot Tiesj', '26', 'Team Sunweb', '', '', ',,']
# ['46', '66', '+10:34', '215', 'rider/cyril-gautier', ' Gautier Cyril', '32', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ['47', '61', '+8:56', '95', 'rider/nelson-oliveira', ' Oliveira Nelson', '31', 'Movistar Team', '', '', ',,']
# ['48', '47', '+4:40', '83', 'rider/warren-barguil', ' Barguil Warren', '28', 'Team Arkéa Samsic', '', '', ',,']
# ['49', '135', '+28:30', '136', 'rider/vegard-stake-laengen', ' Laengen Vegard Stake', '31', 'UAE-Team Emirates', '', '', ',,']
# ['50', '11', '+0:17', '81', 'rider/nairo-quintana', ' Quintana Nairo', '30', 'Team Arkéa Samsic', '', '', ',,']
# ['51', '88', '+18:00', '36', 'rider/nans-peters', ' Peters Nans', '26', 'AG2R La Mondiale', '', '', ',,']
# ['52', '30', '+0:17', '51', 'rider/thibaut-pinot', ' Pinot Thibaut', '30', 'Groupama - FDJ', '', '', ',,']
# ['53', '16', '+0:17', '22', 'rider/emanuel-buchmann', ' Buchmann Emanuel', '27', 'BORA - hansgrohe', '', '', ',,']
# ['54', '117', '+21:53', '206', 'rider/joris-nieuwenhuis', ' Nieuwenhuis Joris', '24', 'Team Sunweb', '', '', ',,']
# ['55', '68', '+10:34', '23', 'rider/felix-grossschartner', ' Großschartner Felix', '26', 'BORA - hansgrohe', '', '', ',,']
# ['56', '75', '+14:07', '205', 'rider/soren-kragh-andersen', 'Kragh Andersen Søren', '26', 'Team Sunweb', '', '', ',,']
# ['57', '26', '+0:17', '61', 'rider/mikel-landa', ' Landa Mikel', '30', 'Bahrain - McLaren', '', '', ',,']
# ['58', '1', '+0:00', '41', 'rider/julian-alaphilippe', ' Alaphilippe Julian', '28', 'Deceuninck - Quick Step', '', '', ',,']
# ['59', '10', '+0:17', '164', 'rider/johan-esteban-chaves', ' Chaves Esteban', '30', 'Mitchelton-Scott', '', '', ',,']
# ['60', '12', '+0:17', '111', 'rider/greg-van-avermaet', 'Van Avermaet Greg', '35', 'CCC Team', '', '', ',,']
# ['61', '25', '+0:17', '91', 'rider/alejandro-valverde', ' Valverde Alejandro', '40', 'Movistar Team', '', '', ',,']
# ['62', '120', '+21:53', '55', 'rider/matthieu-ladagnous', ' Ladagnous Matthieu', '35', 'Groupama - FDJ', '', '', ',,']
# ['63', '3', '+0:07', '204', 'rider/marc-hirschi', ' Hirschi Marc', '22', 'Team Sunweb', '', '', ',,']
# ['64', '136', '+28:30', '214', 'rider/jens-debusschere', ' Debusschere Jens', '31', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ['65', '84', '+18:00', '88', 'rider/connor-swift', ' Swift Connor', '24', 'Team Arkéa Samsic', '', '', ',,']
# ['66', '118', '+21:53', '212', 'rider/cyril-barthe', ' Barthe Cyril', '24', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ['67', '17', '+0:17', '31', 'rider/romain-bardet', ' Bardet Romain', '29', 'AG2R La Mondiale', '', '', ',,']
# ['68', '110', '+20:57', '165', 'rider/daryl-impey', ' Impey Daryl', '35', 'Mitchelton-Scott', '', '', ',,']
# ['69', '151', '+29:10', '163', 'rider/sam-bewley', ' Bewley Sam', '33', 'Mitchelton-Scott', '', '', ',,']
# ['70', '148', '+29:10', '193', 'rider/ryan-gibbons', ' Gibbons Ryan', '26', 'NTT Pro Cycling', '', '', ',,']
# ['71', '14', '+0:17', '3', 'rider/richard-carapaz', ' Carapaz Richard', '27', 'INEOS Grenadiers', '', '', ',,']
# ['72', '15', '+0:17', '11', 'rider/primoz-roglic', ' Roglič Primož', '30', 'Team Jumbo-Visma', '', '', ',,']
# ['73', '95', '+18:00', '96', 'rider/jose-joaquin-rojas', ' Rojas José Joaquín', '35', 'Movistar Team', '', '', ',,']
# ['74', '39', '+1:31', '12', 'rider/george-bennett', ' Bennett George', '30', 'Team Jumbo-Visma', '', '', ',,']
# ['75', '42', '+2:24', '56', 'rider/valentin-madouas', ' Madouas Valentin', '24', 'Groupama - FDJ', '', '', ',,']
# ['76', '87', '+18:00', '13', 'rider/amund-grondahl-jansen', ' Jansen Amund Grøndahl', '26', 'Team Jumbo-Visma', '', '', ',,']
# ['77', '64', '+10:10', '86', 'rider/diego-rosa', ' Rosa Diego', '31', 'Team Arkéa Samsic', '', '', ',,']
# ['78', '36', '+0:34', '144', 'rider/gorka-izagirre', ' Izagirre Gorka', '32', 'Astana Pro Team', '', '', ',,']
# ['79', '94', '+18:00', '54', 'rider/stefan-kung', ' Küng Stefan', '26', 'Groupama - FDJ', '', '', ',,']
# ['80', '63', '+8:56', '102', 'rider/niklas-eg', ' Eg Niklas', '25', 'Trek - Segafredo', '', '', ',,']
# ['81', '18', '+0:17', '104', 'rider/bauke-mollema', ' Mollema Bauke', '33', 'Trek - Segafredo', '', '', ',,']
# ['82', '92', '+18:00', '8', 'rider/dylan-van-baarle', 'van Baarle Dylan', '28', 'INEOS Grenadiers', '', '', ',,']
# ['83', '40', '+2:24', '16', 'rider/sepp-kuss', ' Kuss Sepp', '25', 'Team Jumbo-Visma', '', '', ',,']
# ['84', '22', '+0:17', '94', 'rider/enric-mas', ' Mas Enric', '25', 'Movistar Team', '', '', ',,']
# ['85', '137', '+28:30', '65', 'rider/marco-haller', ' Haller Marco', '29', 'Bahrain - McLaren', '', '', ',,']
# ['86', '109', '+20:57', '127', 'rider/pierre-luc-perichon', ' Périchon Pierre-Luc', '33', 'Cofidis, Solutions Crédits', '', '', ',,']
# ['87', '44', '+3:53', '76', 'rider/daniel-felipe-martinez', ' Martínez Daniel Felipe', '24', 'EF Pro Cycling', '', '', ',,']
# ['88', '113', '+20:57', '66', 'rider/matej-mohoric', ' Mohorič Matej', '25', 'Bahrain - McLaren', '', '', ',,']
# ['89', '41', '+2:24', '132', 'rider/fabio-aru', ' Aru Fabio', '30', 'UAE-Team Emirates', '', '', ',,']
# ['90', '20', '+0:17', '34', 'rider/pierre-latour', ' Latour Pierre', '26', 'AG2R La Mondiale', '', '', ',,']
# ['91', '51', '+4:40', '186', 'rider/romain-sicard', ' Sicard Romain', '32', 'Team Total Direct Energie', '', '', ',,']
# ['92', '23', '+0:17', '72', 'rider/alberto-bettiol', ' Bettiol Alberto', '26', 'EF Pro Cycling', '', '', ',,']
# ['93', '8', '+0:17', '74', 'rider/sergio-higuita', ' Higuita Sergio', '23', 'EF Pro Cycling', '', '', ',,']
# ['94', '76', '+14:07', '77', 'rider/neilson-powless', ' Powless Neilson', '23', 'EF Pro Cycling', '', '', ',,']
# ['95', '28', '+0:17', '208', 'rider/nicolas-roche', ' Roche Nicolas', '36', 'Team Sunweb', '', '', ',,']
# ['96', '38', '+1:31', '197', 'rider/domenico-pozzovivo', ' Pozzovivo Domenico', '37', 'NTT Pro Cycling', '', '', ',,']
# ['97', '29', '+0:17', '71', 'rider/rigoberto-uran', ' Urán Rigoberto', '33', 'EF Pro Cycling', '', '', ',,']
# ['98', '69', '+10:34', '106', 'rider/toms-skujins', ' Skujiņš Toms', '29', 'Trek - Segafredo', '', '', ',,']
# ['99', '45', '+3:53', '73', 'rider/hugh-carthy', ' Carthy Hugh', '26', 'EF Pro Cycling', '', '', ',,']
# ['100', '34', '+0:17', '101', 'rider/richie-porte', ' Porte Richie', '35', 'Trek - Segafredo', '', '', ',,']
# ['101', '27', '+0:17', '218', 'rider/pierre-rolland', ' Rolland Pierre', '33', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ['102', '33', '+0:17', '124', 'rider/jesus-herrada-lopez', ' Herrada Jesús', '30', 'Cofidis, Solutions Crédits', '', '', ',,']
# ['103', '150', '+29:10', '198', 'rider/max-walscheid', ' Walscheid Max', '27', 'NTT Pro Cycling', '', '', ',,']
# ['104', '149', '+29:10', '217', 'rider/kevin-reza', ' Reza Kévin', '32', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ['105', '52', '+4:40', '145', 'rider/ion-izagirre', ' Izagirre Ion', '31', 'Astana Pro Team', '', '', ',,']
# ['106', '62', '+8:56', '15', 'rider/robert-gesink', ' Gesink Robert', '34', 'Team Jumbo-Visma', '', '', ',,']
# ['107', '50', '+4:40', '118', 'rider/ilnur-zakarin', ' Zakarin Ilnur', '30', 'CCC Team', '', '', ',,']
# ['108', '99', '+18:00', '53', 'rider/david-gaudu', ' Gaudu David', '23', 'Groupama - FDJ', '', '', ',,']
# ['109', '70', '+10:34', '24', 'rider/lennard-kamna', ' Kämna Lennard', '23', 'BORA - hansgrohe', '', '', ',,']
# ['110', '49', '+4:40', '168', 'rider/mikel-nieve', ' Nieve Mikel', '36', 'Mitchelton-Scott', '', '', ',,']
# ['111', '48', '+4:40', '123', 'rider/nicolas-edet', ' Edet Nicolas', '32', 'Cofidis, Solutions Crédits', '', '', ',,']
# ['112', '91', '+18:00', '78', 'rider/tejay-van-garderen', 'van Garderen Tejay', '32', 'EF Pro Cycling', '', '', ',,']
# ['113', '97', '+18:00', '177', 'rider/nils-politt', ' Politt Nils', '26', 'Israel Start-Up Nation', '', '', ',,']
# ['114', '35', '+0:17', '62', 'rider/pello-bilbao', ' Bilbao Pello', '30', 'Bahrain - McLaren', '', '', ',,']
# ['115', '58', '+7:17', '47', 'rider/bob-jungels', ' Jungels Bob', '27', 'Deceuninck - Quick Step', '', '', ',,']
# ['116', '170', '+42:14', '152', 'rider/steff-cras', ' Cras Steff', '24', 'Lotto Soudal', '', '', ',,']
# ['117', '101', '+18:00', '64', 'rider/sonny-colbrelli', ' Colbrelli Sonny', '30', 'Bahrain - McLaren', '', '', ',,']
# ['118', '89', '+18:00', '42', 'rider/kasper-asgreen', ' Asgreen Kasper', '25', 'Deceuninck - Quick Step', '', '', ',,']
# ['119', '71', '+10:34', '92', 'rider/dario-cataldo', ' Cataldo Dario', '35', 'Movistar Team', '', '', ',,']
# ['120', '32', '+0:17', '103', 'rider/kenny-elissonde', ' Elissonde Kenny', '29', 'Trek - Segafredo', '', '', ',,']
# ['121', '43', '+2:24', '57', 'rider/rudy-molard', ' Molard Rudy', '30', 'Groupama - FDJ', '', '', ',,']
# ['122', '141', '+28:30', '213', 'rider/maxime-chevalier', ' Chevalier Maxime', '21', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ['123', '31', '+0:17', '28', 'rider/maximilian-schachmann', ' Schachmann Maximilian', '26', 'BORA - hansgrohe', '', '', ',,']
# ['124', '162', '+33:21', '183', 'rider/lilian-calmejane', ' Calmejane Lilian', '27', 'Team Total Direct Energie', '', '', ',,']
# ['125', '46', '+3:53', '38', 'rider/alexis-vuillermoz', ' Vuillermoz Alexis', '32', 'AG2R La Mondiale', '', '', ',,']
# ['126', '77', '+14:38', '173', 'rider/ben-hermans', ' Hermans Ben', '34', 'Israel Start-Up Nation', '', '', ',,']
# ['127', '138', '+28:30', '207', 'rider/casper-pedersen', ' Pedersen Casper', '24', 'Team Sunweb', '', '', ',,']
# ['128', '169', '+40:14', '154', 'rider/thomas-de-gendt', 'De Gendt Thomas', '33', 'Lotto Soudal', '', '', ',,']
# ['129', '102', '+18:20', '113', 'rider/simon-geschke', ' Geschke Simon', '34', 'CCC Team', '', '', ',,']
# ['130', '140', '+28:30', '137', 'rider/marco-marcato', ' Marcato Marco', '36', 'UAE-Team Emirates', '', '', ',,']
# ['131', '112', '+20:57', '195', 'rider/michael-valgren-andersen', ' Valgren Michael', '28', 'NTT Pro Cycling', '', '', ',,']
# ['132', '166', '+34:01', '182', 'rider/mathieu-burgaudeau', ' Burgaudeau Mathieu', '21', 'Team Total Direct Energie', '', '', ',,']
# ['133', '126', '+26:11', '176', 'rider/guy-niv', ' Niv Guy', '26', 'Israel Start-Up Nation', '', '', ',,']
# ['134', '152', '+29:10', '172', 'rider/andre-greipel', ' Greipel André', '38', 'Israel Start-Up Nation', '', '', ',,']
# ['135', '98', '+18:00', '171', 'rider/dan-martin', ' Martin Dan', '34', 'Israel Start-Up Nation', '', '', ',,']
# ['136', '57', '+7:17', '175', 'rider/krists-neilands', ' Neilands Krists', '26', 'Israel Start-Up Nation', '', '', ',,']
# ['137', '139', '+28:30', '2', 'rider/andrey-amador', ' Amador Andrey', '34', 'INEOS Grenadiers', '', '', ',,']
# ['138', '93', '+18:00', '216', 'rider/quentin-pacher', ' Pacher Quentin', '28', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ['139', '100', '+18:00', '116', 'rider/michael-schar', ' Schär Michael', '33', 'CCC Team', '', '', ',,']
# ['140', '53', '+4:40', '148', 'rider/harold-tejada', ' Tejada Harold', '23', 'Astana Pro Team', '', '', ',,']
# ['141', '111', '+20:57', '75', 'rider/jens-keukeleire', ' Keukeleire Jens', '31', 'EF Pro Cycling', '', '', ',,']
# ['142', '59', '+7:17', '4', 'rider/jonathan-castroviejo', ' Castroviejo Jonathan', '33', 'INEOS Grenadiers', '', '', ',,']
# ['143', '96', '+18:00', '192', 'rider/edvald-boasson-hagen', ' Boasson Hagen Edvald', '33', 'NTT Pro Cycling', '', '', ',,']
# ['144', '78', '+15:14', '46', 'rider/dries-devenyns', ' Devenyns Dries', '37', 'Deceuninck - Quick Step', '', '', '0:26']
# ['145', '154', '+29:54', '153', 'rider/jasper-de-buyst', 'De Buyst Jasper', '26', 'Lotto Soudal', '', '', '0:31']
# ['146', '54', '+5:12', '58', 'rider/sebastien-reichenbach', ' Reichenbach Sébastien', '31', 'Groupama - FDJ', '', '', '0:40']
# ['147', '155', '+30:21', '158', 'rider/roger-kluge', ' Kluge Roger', '34', 'Lotto Soudal', '', '', '1:11']
# ['148', '121', '+22:20', '166', 'rider/christopher-juul-jensen', ' Juul-Jensen Christopher', '31', 'Mitchelton-Scott', '', '', '1:23']
# ['149', '164', '+34:00', '6', 'rider/luke-rowe', ' Rowe Luke', '30', 'INEOS Grenadiers', '', '', '1:37']
# ['150', '79', '+16:32', '98', 'rider/carlos-verona', ' Verona Carlos', '27', 'Movistar Team', '', '', '2:25']
# ['151', '104', '+20:50', '196', 'rider/roman-kreuziger', ' Kreuziger Roman', '34', 'NTT Pro Cycling', '', '', '2:50']
# ['152', '160', '+32:00', '156', 'rider/frederik-frison', ' Frison Frederik', '28', 'Lotto Soudal', '', '', ',,']
# ['153', '103', '+20:50', '194', 'rider/michael-gogl', ' Gogl Michael', '26', 'NTT Pro Cycling', '', '', ',,']
# ['154', '158', '+32:00', '185', 'rider/fabien-grellier', ' Grellier Fabien', '25', 'Team Total Direct Energie', '', '', ',,']
# ['155', '161', '+32:00', '52', 'rider/william-bonnet', ' Bonnet William', '38', 'Groupama - FDJ', '', '', ',,']
# ['156', '105', '+20:50', '45', 'rider/tim-declercq', ' Declercq Tim', '31', 'Deceuninck - Quick Step', '', '', ',,']
# ['157', '157', '+31:20', '187', 'rider/geoffrey-soupe', ' Soupe Geoffrey', '32', 'Team Total Direct Energie', '', '', ',,']
# ['158', '159', '+32:00', '133', 'rider/david-de-la-cruz', 'de la Cruz David', '31', 'UAE-Team Emirates', '', '', ',,']
# ['159', '106', '+20:56', '114', 'rider/jan-hirt', ' Hirt Jan', '29', 'CCC Team', '', '', ',,']
# ['160', '114', '+21:42', '112', 'rider/alessandro-de-marchi', 'De Marchi Alessandro', '34', 'CCC Team', '', '', '3:42']
# ['161', '172', '+46:45', '7', 'rider/pavel-sivakov', ' Sivakov Pavel', '23', 'INEOS Grenadiers', '', '', '5:11']
# ['162', '56', '+6:30', '5', 'rider/michal-kwiatkowski', ' Kwiatkowski Michał', '30', 'INEOS Grenadiers', '', '', ',,']
# ['163', '73', '+12:28', '82', 'rider/winner-anacona', ' Anacona Winner', '32', 'Team Arkéa Samsic', '', '', ',,']
# ['164', '156', '+31:13', '67', 'rider/wout-poels', ' Poels Wout', '32', 'Bahrain - McLaren', '', '', ',,']
# ['165', '124', '+23:11', '33', 'rider/benoit-cosnefroy', ' Cosnefroy Benoît', '24', 'AG2R La Mondiale', '', '', ',,']
# ['166', '163', '+33:41', '44', 'rider/remi-cavagna', ' Cavagna Rémi', '25', 'Deceuninck - Quick Step', '', '', ',,']
# ['167', '72', '+12:28', '32', 'rider/mikael-cherel', ' Cherel Mikaël', '34', 'AG2R La Mondiale', '', '', ',,']
# ['168', '60', '+7:35', '18', 'rider/wout-van-aert', 'van Aert Wout', '25', 'Team Jumbo-Visma', '', '', ',,']
# ['169', '123', '+23:11', '17', 'rider/tony-martin', ' Martin Tony', '35', 'Team Jumbo-Visma', '', '', ',,']
# ['170', '171', '+45:25', '184', 'rider/jerome-cousin', ' Cousin Jérôme', '31', 'Team Total Direct Energie', '', '', ',,']
# ['171', '122', '+23:11', '85', 'rider/dayer-quintana-rojas', ' Quintana Dayer', '28', 'Team Arkéa Samsic', '', '', ',,']
# ['172', '125', '+25:32', '27', 'rider/lukas-postlberger', ' Pöstlberger Lukas', '28', 'BORA - hansgrohe', '', '', '7:32']
# UPDATING 1:stage has 172 participants
# ERROR: ['DNF', '', '+ - 13:59:17', '126', 'rider/anthony-perez', ' Perez Anthony', '29', 'Cofidis, Solutions Crédits', '', '', '-']
# ['1', '1', '-', '41', 'rider/julian-alaphilippe', ' Alaphilippe Julian', '28', 'Deceuninck - Quick Step', ' 13:59:17', '..', '2']
# ['2', '-', '161', 'rider/adam-yates', ' Yates Adam', '28', 'Mitchelton-Scott', '0:04', '..', '3', '3']
# UPDATING 1:gc has 2 participants
# ERROR: ['-', '204', 'rider/marc-hirschi', ' Hirschi Marc', '22', 'Team Sunweb', '0:07', '..', '4', '5', '▲1']
# ['131', 'rider/tadej-pogacar', ' Pogačar Tadej', '21', 'UAE-Team Emirates', '0:17', '..', '5', '7', '▲2']
# UPDATING 1:green has 1 participants
# ['134', 'rider/davide-formolo', ' Formolo Davide', '27', 'UAE-Team Emirates', ',,', '..', '6', '8', '▲2', '1']
# UPDATING 1:youth has 1 participants

# %%
stage_df = pd.DataFrame(data['gc'], gc_col = ['gcPos', 'prevGcPos', 'gcChng', 'bib', 'url', 'name', 'age', 'team', 'uciGc', 'gcTime', 'more'])
stage_df.head()
# Out:
#   stagePos posChange                       url                 name age  \
# 0        1                 rider/arnaud-demare        Démare Arnaud  28
# 1        2                 rider/bryan-coquard        Coquard Bryan  28
# 2        3            rider/julian-alaphilippe   Alaphilippe Julian  28
# 3        4             rider/clement-venturini    Venturini Clément  26
# 4        5                rider/anthony-turgis       Turgis Anthony  26
#
#                              teamName  uci pnts stageTime
# 0                      Groupama - FDJ  100   15   5:38:27
# 1  B&B Hotels - Vital Concept p/b KTM   75   10        ,,
# 2             Deceuninck - Quick Step   60    7        ,,
# 3                    AG2R La Mondiale   50    4      0:05
# 4           Team Total Direct Energie   40    2        ,,

# %%
ONE_DAY_RACE = 0
FIRST_STAGE_IN_TOUR = 1
OTHER_TOUR_STAGE = 2
ITT = 3

def fix_time(data, time_col):
    tdf = data[data[time_col] == ',,'][[time_col]]
    to_change_ix = list(tdf.index)
    data.loc[data.index.isin(to_change_ix), time_col] = None
    data[time_col] = data[time_col].fillna(method='ffill')
    return data

def build_df(data, result_type):
    if result_type == ONE_DAY_RACE:
        stage_col = ['stagePos', 'gcPos', 'url', 'name', 'age', 'teamName', 'uciStage', 'pnt', 'stageTime']
    elif result_type == ITT:
        stage_col = ['stagePos', 'gcPos', 'timeAdd', 'bib', 'url', 'name', 'age', 'teamName', 'uciStage','pnt', 'stgAvgPace', 'stageTime']
    elif result_type == FIRST_STAGE_IN_TOUR:
        stage_col = ['stagePos', 'gcPos', 'timeAdd', 'bib', 'url', 'name', 'age', 'teamName', 'uciStage','pnt', 'stageTime']
        gc_col = ['gcPos', 'bib', 'url', 'name', 'age', 'team', 'uciGc', 'gcTime', 'more']
        green_col = ['greenPos', 'bib', 'url', 'name', 'age', 'team', 'greenPnts', 'greenPntsChng']
        youth_col = ['youthPos', 'gcPos', 'timeAdd', 'bib', 'url', 'name', 'age', 'team', 'youthTime']
        kom_col = ['komPos', 'bib', 'url', 'name', 'age', 'team', 'komPnts',  'komPntsChng']
        teams_col = ['teamPos', 'empty', 'teamName', 'teamTime']
    elif result_type == OTHER_TOUR_STAGE:
        stage_col = ['stagePos', 'gcPos', 'gcTime', 'bib', 'url', 'name', 'age', 'teamName', 'uciStage','pnt', 'stageTime']
        gc_col = ['gcPos', 'prevGcPos', 'gcChng', 'bib', 'url', 'name', 'age', 'team', 'uciGc', 'gcTime', 'more']
        green_col = ['greenPos', 'prevGreenPos', 'greenChng', 'bib', 'url', 'name', 'age', 'team', 'greenPnts', 'greenPntsChng']
        youth_col = ['youthPos', 'prevYouthPos', 'youthChng', 'gcPos', 'gcTime', 'bib', 'url', 'name', 'age', 'team', 'youthTime']
        kom_col = ['komPos', 'prevKomPos', 'komChng', 'bib', 'url', 'name', 'age', 'team', 'komPnts',  'komPntsChng']
        teams_col = ['teamPos', 'prevTeamPos', 'teamChng', 'empty', 'teamName', 'teamTime']
    
    stage_df = pd.DataFrame(data['stage'], columns=stage_col)
    stage_df = fix_time(stage_df, 'stageTime')
    
    if result_type in [FIRST_STAGE_IN_TOUR, OTHER_TOUR_STAGE]:
        # one day races only have 1 data frame
        stage_df = stage_df.set_index('bib')
        gc_df = pd.DataFrame(data['gc'], columns=gc_col)
        gc_df = gc_df[['bib', 'uciGc']].set_index('bib')

        green_df = pd.DataFrame(data['green'], columns=green_col)
        green_df = green_df[['bib', 'greenPos', 'greenPnts']].set_index('bib')

        youth_df = pd.DataFrame(data['youth'], columns=youth_col)
        youth_df = youth_df[['bib', 'youthPos', 'youthTime']].set_index('bib')
        youth_df = fix_time(youth_df, 'youthTime')

        kom_df= pd.DataFrame(data['kom'], columns=kom_col)
        kom_df = kom_df[['bib', 'komPos', 'komPnts']].set_index('bib')

        team_df = pd.DataFrame(data['teams'], columns=teams_col)
        team_df = team_df[['teamPos', 'teamName', 'teamTime']]

        df = pd.concat([stage_df, gc_df, green_df, youth_df, kom_df], axis=1, sort=False)
        return df
    else:
        return stage_df

df = build_df(data, ITT)
df.head()
# Out:
#   stagePos gcPos timeAdd bib                          url  \
# 0        1     2   +0:58  98   rider/soren-kragh-andersen
# 1        2     1   +0:00  37  rider/maximilian-schachmann
# 2        3    23   +2:16  42         rider/kasper-asgreen
# 3        4    85  +14:52  64        rider/thomas-de-gendt
# 4        5    29   +3:41  82           rider/pello-bilbao
#
#                      name age                 teamName uciStage pnt  \
# 0    Kragh Andersen Søren  25              Team Sunweb       60  50
# 1   Schachmann Maximilian  26         BORA - hansgrohe       25  30
# 2          Asgreen Kasper  25  Deceuninck - Quick Step       10  18
# 3         De Gendt Thomas  33             Lotto Soudal           13
# 4            Bilbao Pello  30        Bahrain - McLaren           10
#
#   stgAvgPace stageTime
# 0     48.064     18:51
# 1     47.810      0:06
# 2     47.559      0:12
# 3     47.517      0:13
# 4     47.435      0:15

# %%
# get the points classifications
def get_points(url):
    ''' Extract all the races in the season for the rider on the rider's profile (url)'''
    page = requests.get(url)
    stage_html = BeautifulSoup(page.content, 'html.parser')
    
    if 'One day race' in str(stage_html.h2):
        print('ONE DAY RACE')
        data_row_length = {'stage': 9}
        result_type = ONE_DAY_RACE
    elif '(ITT)' in str(stage_html.h2):
        print('(ITT)')
        data_row_length = {'stage': 12}
        result_type = ITT
    elif url.endswith('/result') or url.endswith('/stage-1'):
        result_type = FIRST_STAGE_IN_TOUR
        data_row_length = {'stage': 11, 'gc': 9, 'green': 8, 'youth': 9, 'kom': 8, 'teams': 4}
    else:
        result_type = OTHER_TOUR_STAGE
        data_row_length = {'stage': 11, 'gc': 11, 'green': 10, 'youth': 11, 'kom': 10, 'teams': 6}
    data = get_stage_data(stage_html, data_row_length)
    df = build_df(data, result_type)
    return df
    
    
url_uniques = stages_df.url.unique()
count = 0
all_races = list()
print(len(url_uniques))
for uix, url in enumerate(url_uniques):
    
    stage_url = 'https://www.procyclingstats.com/{}'.format(url)
    print('{} in {}: {}'.format(uix, len(url_uniques), stage_url))
    #stage_url = 'https://www.procyclingstats.com/race/tour-de-france/2020/stage-2'
    rdf = get_points(stage_url)
    all_races.append(rdf)
    #if count == 5: break
# Out:
# 190
# 0 in 190: race/tour-de-france/2020/stage-9
# UPDATING 1:stage has 166 participants
# ERROR: ['DNF', '', '+ - 38:40:01', '132', 'rider/fabio-aru', ' Aru Fabio', '30', 'UAE-Team Emirates', '', '', '-']
# ERROR: ['DNF', '', '+ - 38:40:01', '152', 'rider/steff-cras', ' Cras Steff', '24', 'Lotto Soudal', '', '', ',,']
# UPDATING 1:gc has 166 participants
# UPDATING 1:green has 102 participants
# UPDATING 1:youth has 25 participants
# UPDATING 1:kom has 43 participants
# UPDATING 1:teams has 22 participants
# 1 in 190: race/tour-de-france/2020/stage-8
# UPDATING 1:stage has 168 participants
# ERROR: ['DNF', '', '+ - 34:44:52', '191', 'rider/giacomo-nizzolo', ' Nizzolo Giacomo', '31', 'NTT Pro Cycling', '', '', '-']
# ERROR: ['DNF', '', '+ - 34:44:52', '52', 'rider/william-bonnet', ' Bonnet William', '38', 'Groupama - FDJ', '', '', ',,']
# ERROR: ['DNF', '', '+ - 34:44:52', '86', 'rider/diego-rosa', ' Rosa Diego', '31', 'Team Arkéa Samsic', '', '', ',,']
# ERROR: ['DNF', '', '+ - 34:44:52', '183', 'rider/lilian-calmejane', ' Calmejane Lilian', '27', 'Team Total Direct Energie', '', '', ',,']
# UPDATING 1:gc has 168 participants
# UPDATING 1:green has 95 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 36 participants
# UPDATING 1:teams has 22 participants
# 2 in 190: race/tour-de-france/2020/stage-7
# UPDATING 1:stage has 172 participants
# UPDATING 1:gc has 172 participants
# UPDATING 1:green has 89 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 31 participants
# UPDATING 1:teams has 22 participants
# 3 in 190: race/tour-de-france/2020/stage-6
# UPDATING 1:stage has 172 participants
# UPDATING 1:gc has 172 participants
# UPDATING 1:green has 83 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 28 participants
# UPDATING 1:teams has 22 participants
# 4 in 190: race/tour-de-france/2020/stage-5
# UPDATING 1:stage has 172 participants
# UPDATING 1:gc has 172 participants
# UPDATING 1:green has 78 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 23 participants
# UPDATING 1:teams has 22 participants
# 5 in 190: race/tour-de-france/2020/stage-4
# UPDATING 1:stage has 172 participants
# UPDATING 1:gc has 172 participants
# UPDATING 1:green has 72 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 23 participants
# UPDATING 1:teams has 22 participants
# 6 in 190: race/tour-de-france/2020/stage-3
# UPDATING 1:stage has 172 participants
# ERROR: ['DNF', '', '+ - 13:59:17', '126', 'rider/anthony-perez', ' Perez Anthony', '29', 'Cofidis, Solutions Crédits', '', '', '-']
# UPDATING 1:gc has 2 participants
# ERROR: ['-', '204', 'rider/marc-hirschi', ' Hirschi Marc', '22', 'Team Sunweb', '0:07', '..', '4', '5', '▲1']
# UPDATING 1:green has 1 participants
# UPDATING 1:youth has 1 participants
# 7 in 190: race/tour-de-france/2020/stage-2
# UPDATING 1:stage has 173 participants
# ERROR: ['DNS', '', '+ -8:41:35', '68', 'rider/rafael-valls', ' Valls Rafael', '33', 'Bahrain - McLaren', '', '', '-']
# ERROR: ['DNS', '', '+ -8:41:35', '157', 'rider/philippe-gilbert', ' Gilbert Philippe', '38', 'Lotto Soudal', '', '', ',,']
# UPDATING 1:gc has 173 participants
# UPDATING 1:green has 48 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 14 participants
# UPDATING 1:teams has 22 participants
# 8 in 190: race/tour-de-france/2020/stage-1
# UPDATING 1:stage has 175 participants
# ERROR: ['OTL', '', '+ -3:46:13', '155', 'rider/john-degenkolb', ' Degenkolb John', '31', 'Lotto Soudal', '', '', '-']
# UPDATING 1:gc has 175 participants
# UPDATING 1:green has 24 participants
# UPDATING 1:youth has 26 participants
# UPDATING 1:kom has 3 participants
# UPDATING 1:teams has 22 participants
# 9 in 190: race/nc-france/2020/result
# ONE DAY RACE
# UPDATING 1:stage has 93 participants
# UPDATING 1:gc has 0 participants
# 10 in 190: race/dauphine/2020/stage-5
# UPDATING 1:stage has 106 participants
# ERROR: ['OTL', '', '+ - 21:44:58', '226', 'rider/sebastian-schonberger', ' Schönberger Sebastian', '26', 'B&B Hotels - Vital Concept p/b KTM', '', '', '-']
# ERROR: ['OTL', '', '+ - 21:44:58', '222', 'rider/maxime-chevalier', ' Chevalier Maxime', '21', 'B&B Hotels - Vital Concept p/b KTM', '', '', '-']
# ERROR: ['OTL', '', '+ - 21:44:58', '137', 'rider/clement-russo', ' Russo Clément', '25', 'Team Arkéa Samsic', '', '', ',,']
# ERROR: ['OTL', '', '+ - 21:44:58', '66', 'rider/tony-martin', ' Martin Tony', '35', 'Team Jumbo-Visma', '', '', '-']
# ERROR: ['OTL', '', '+ - 21:44:58', '215', 'rider/alexander-evans', ' Evans Alexander', '23', 'Circus - Wanty Gobert', '', '', '-']
# ERROR: ['OTL', '', '+ - 21:44:58', '197', 'rider/geoffrey-soupe', ' Soupe Geoffrey', '32', 'Team Total Direct Energie', '', '', ',,']
# ERROR: ['OTL', '', '+ - 21:44:58', '85', 'rider/alexander-kristoff', ' Kristoff Alexander', '33', 'UAE-Team Emirates', '', '', '-']
# ERROR: ['DNF', '', '+ - 21:44:58', '194', 'rider/jerome-cousin', ' Cousin Jérôme', '31', 'Team Total Direct Energie', '', '', '-']
# ERROR: ['DNF', '', '+ - 21:44:58', '136', 'rider/diego-rosa', ' Rosa Diego', '31', 'Team Arkéa Samsic', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '26', 'rider/peter-sagan', ' Sagan Peter', '30', 'BORA - hansgrohe', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '166', 'rider/pierre-luc-perichon', ' Périchon Pierre-Luc', '33', 'Cofidis, Solutions Crédits', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '131', 'rider/nairo-quintana', ' Quintana Nairo', '30', 'Team Arkéa Samsic', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '195', 'rider/fabien-grellier', ' Grellier Fabien', '25', 'Team Total Direct Energie', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '141', 'rider/roman-kreuziger', ' Kreuziger Roman', '34', 'NTT Pro Cycling', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '34', 'rider/michal-kwiatkowski', ' Kwiatkowski Michał', '30', 'Team INEOS', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '182', 'rider/sander-armee', ' Armée Sander', '34', 'Lotto Soudal', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '132', 'rider/winner-anacona', ' Anacona Winner', '32', 'Team Arkéa Samsic', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '207', 'rider/lukasz-wisniowski', ' Wiśniowski Łukasz', '28', 'CCC Team', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '142', 'rider/michael-gogl', ' Gogl Michael', '26', 'NTT Pro Cycling', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '96', 'rider/marc-soler', ' Soler Marc', '26', 'Movistar Team', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '184', 'rider/remy-mertz', ' Mertz Rémy', '25', 'Lotto Soudal', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '134', 'rider/maxime-bouet', ' Bouet Maxime', '33', 'Team Arkéa Samsic', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '217', 'rider/xandro-meurisse', ' Meurisse Xandro', '28', 'Circus - Wanty Gobert', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '143', 'rider/edvald-boasson-hagen', ' Boasson Hagen Edvald', '33', 'NTT Pro Cycling', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '104', 'rider/damien-howson', ' Howson Damien', '28', 'Mitchelton-Scott', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '191', 'rider/rein-taaramae', ' Taaramäe Rein', '33', 'Team Total Direct Energie', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '135', 'rider/dayer-quintana-rojas', ' Quintana Dayer', '28', 'Team Arkéa Samsic', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '25', 'rider/daniel-oss', ' Oss Daniel', '33', 'BORA - hansgrohe', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '144', 'rider/michael-valgren-andersen', ' Valgren Michael', '28', 'NTT Pro Cycling', '', '', ',,']
# ERROR: ['DNF', '', '+ - 21:44:58', '107', 'rider/nick-schultz', ' Schultz Nick', '25', 'Mitchelton-Scott', '', '', ',,']
# ERROR: ['DNS', '', '+ - 21:44:58', '61', 'rider/primoz-roglic', ' Roglič Primož', '30', 'Team Jumbo-Visma', '', '', ',,']
# ERROR: ['DNS', '', '+ - 21:44:58', '73', 'rider/benoit-cosnefroy', ' Cosnefroy Benoît', '24', 'AG2R La Mondiale', '', '', ',,']
# ERROR: ['DNS', '', '+ - 21:44:58', '2', 'rider/omar-fraile', ' Fraile Omar', '30', 'Astana Pro Team', '', '', ',,']
# UPDATING 1:gc has 1 participants
# UPDATING 1:green has 1 participants
# UPDATING 1:youth has 1 participants
# 11 in 190: race/dauphine/2020/stage-4
# UPDATING 1:stage has 139 participants
# ERROR: ['DNF', '', '+ - 17:45:32', '212', 'rider/jeremy-bellicaud', ' Bellicaud Jeremy', '22', 'Circus - Wanty Gobert', '', '', '-']
# ERROR: ['DNF', '', '+ - 17:45:32', '21', 'rider/emanuel-buchmann', ' Buchmann Emanuel', '27', 'BORA - hansgrohe', '', '', ',,']
# ERROR: ['DNF', '', '+ - 17:45:32', '82', 'rider/sven-erik-bystrom', ' Bystrøm Sven Erik', '28', 'UAE-Team Emirates', '', '', ',,']
# ERROR: ['DNF', '', '+ - 17:45:32', '24', 'rider/gregor-muhlberger', ' Mühlberger Gregor', '26', 'BORA - hansgrohe', '', '', ',,']
# ERROR: ['DNF', '', '+ - 17:45:32', '93', 'rider/nelson-oliveira', ' Oliveira Nelson', '31', 'Movistar Team', '', '', ',,']
# ERROR: ['DNF', '', '+ - 17:45:32', '27', 'rider/andreas-schillinger', ' Schillinger Andreas', '37', 'BORA - hansgrohe', '', '', ',,']
# ERROR: ['DNF', '', '+ - 17:45:32', '172', 'rider/andre-greipel', ' Greipel André', '38', 'Israel Start-Up Nation', '', '', ',,']
# ERROR: ['DNF', '', '+ - 17:45:32', '43', 'rider/antoine-duchesne', ' Duchesne Antoine', '28', 'Groupama - FDJ', '', '', ',,']
# ERROR: ['DNF', '', '+ - 17:45:32', '187', 'rider/jelle-wallays', ' Wallays Jelle', '31', 'Lotto Soudal', '', '', ',,']
# ERROR: ['DNF', '', '+ - 17:45:32', '64', 'rider/steven-kruijswijk', ' Kruijswijk Steven', '33', 'Team Jumbo-Visma', '', '', ',,']
# ERROR: ['DNS', '', '+ - 17:45:32', '31', 'rider/egan-bernal', ' Bernal Egan', '23', 'Team INEOS', '', '', ',,']
# ERROR: ['DNS', '', '+ - 17:45:32', '176', 'rider/nils-politt', ' Politt Nils', '26', 'Israel Start-Up Nation', '', '', ',,']
# UPDATING 1:gc has 139 participants
# UPDATING 1:green has 34 participants
# UPDATING 1:youth has 24 participants
# UPDATING 1:kom has 37 participants
# UPDATING 1:teams has 23 participants
# 12 in 190: race/dauphine/2020/stage-3
# UPDATING 1:stage has 151 participants
# ERROR: ['DNF', '', '+ - 13:14:35', '121', 'rider/tiesj-benoot', ' Benoot Tiesj', '26', 'Team Sunweb', '', '', '-']
# ERROR: ['DNF', '', '+ - 13:14:35', '193', 'rider/mathieu-burgaudeau', ' Burgaudeau Mathieu', '21', 'Team Total Direct Energie', '', '', ',,']
# ERROR: ['DNF', '', '+ - 13:14:35', '225', 'rider/quentin-pacher', ' Pacher Quentin', '28', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ERROR: ['DNS', '', '+ - 13:14:35', '114', 'rider/juan-pedro-lopez', ' López Juan Pedro', '23', 'Trek - Segafredo', '', '', ',,']
# ERROR: ['DNS', '', '+ - 13:14:35', '171', 'rider/dan-martin', ' Martin Dan', '33', 'Israel Start-Up Nation', '', '', ',,']
# UPDATING 1:gc has 2 participants
# ERROR: ['-', '21', 'rider/emanuel-buchmann', ' Buchmann Emanuel', '27', 'BORA - hansgrohe', '0:20', '..', '4', '5', '▲1']
# UPDATING 1:green has 1 participants
# UPDATING 1:youth has 1 participants
# 13 in 190: race/dauphine/2020/stage-2
# UPDATING 1:stage has 156 participants
# ERROR: ['DNS', '', '+ -9:07:12', '57', 'rider/mauri-vansevenant', ' Vansevenant Mauri', '21', 'Deceuninck - Quick Step', '', '', '-']
# UPDATING 1:gc has 156 participants
# UPDATING 1:green has 21 participants
# UPDATING 1:youth has 28 participants
# UPDATING 1:kom has 19 participants
# UPDATING 1:teams has 23 participants
# 14 in 190: race/dauphine/2020/stage-1
# UPDATING 1:stage has 157 participants
# ERROR: ['DNF', '', '+ -5:27:32', '204', 'rider/jan-hirt', ' Hirt Jan', '29', 'CCC Team', '', '', '-']
# ERROR: ['DNF', '', '+ -5:27:32', '216', 'rider/quinten-hermans', ' Hermans Quinten', '25', 'Circus - Wanty Gobert', '', '', ',,']
# ERROR: ['DNF', '', '+ -5:27:32', '185', 'rider/brent-van-moer', 'Van Moer Brent', '22', 'Lotto Soudal', '', '', ',,']
# ERROR: ['DNF', '', '+ -5:27:32', '192', 'rider/niccolo-bonifazio', ' Bonifazio Niccolò', '26', 'Team Total Direct Energie', '', '', ',,']
# UPDATING 1:gc has 1 participants
# UPDATING 1:green has 1 participants
# UPDATING 1:youth has 1 participants
# 15 in 190: race/milano-sanremo/2020/result
# ONE DAY RACE
# UPDATING 1:stage has 149 participants
# UPDATING 1:gc has 0 participants
# 16 in 190: race/strade-bianche/2020/result
# ONE DAY RACE
# UPDATING 1:stage has 42 participants
# UPDATING 1:gc has 0 participants
# 17 in 190: race/paris-nice/2020/stage-7
# UPDATING 1:stage has 61 participants
# ERROR: ['DNF', '', '+ - 27:14:23', '36', 'rider/juraj-sagan', ' Sagan Juraj', '31', 'BORA - hansgrohe', '', '', '-']
# ERROR: ['DNF', '', '+ - 27:14:23', '105', 'rider/thomas-scully', ' Scully Tom', '30', 'EF Pro Cycling', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '122', 'rider/victor-campenaerts', ' Campenaerts Victor', '28', 'NTT Pro Cycling', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '54', 'rider/alexis-gougeard', ' Gougeard Alexis', '27', 'AG2R La Mondiale', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '15', 'rider/daniel-mclay', ' McLay Daniel', '28', 'Team Arkéa Samsic', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '156', 'rider/boy-van-poppel', 'van Poppel Boy', '32', 'Circus - Wanty Gobert', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '111', 'rider/lilian-calmejane', ' Calmejane Lilian', '27', 'Team Total Direct Energie', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '38', 'rider/michael-schwarzmann', ' Schwarzmann Michael', '29', 'BORA - hansgrohe', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '77', 'rider/damien-touze', ' Touzé Damien', '23', 'Cofidis, Solutions Crédits', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '124', 'rider/michael-gogl', ' Gogl Michael', '26', 'NTT Pro Cycling', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '53', 'rider/benoit-cosnefroy', ' Cosnefroy Benoît', '24', 'AG2R La Mondiale', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '26', 'rider/tobias-ludvigsson', ' Ludvigsson Tobias', '29', 'Groupama - FDJ', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '158', 'rider/pieter-vanspeybrouck', ' Vanspeybrouck Pieter', '33', 'Circus - Wanty Gobert', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '113', 'rider/jonathan-hivert', ' Hivert Jonathan', '34', 'Team Total Direct Energie', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '67', 'rider/frederik-frison', ' Frison Frederik', '27', 'Lotto Soudal', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '74', 'rider/cyril-lemoine', ' Lemoine Cyril', '37', 'Cofidis, Solutions Crédits', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '145', 'rider/ramunas-navardauskas', ' Navardauskas Ramūnas', '32', 'NIPPO DELKO One Provence', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '46', 'rider/yves-lampaert', ' Lampaert Yves', '28', 'Deceuninck - Quick Step', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '28', 'rider/marc-sarreau', ' Sarreau Marc', '26', 'Groupama - FDJ', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '161', 'rider/bryan-coquard', ' Coquard Bryan', '27', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '114', 'rider/adrien-petit', ' Petit Adrien', '29', 'Team Total Direct Energie', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '58', 'rider/nans-peters', ' Peters Nans', '26', 'AG2R La Mondiale', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '4', 'rider/alex-kirsch', ' Kirsch Alex', '27', 'Trek - Segafredo', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '146', 'rider/dusan-rajovic', ' Rajović Dušan', '22', 'NIPPO DELKO One Provence', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '31', 'rider/peter-sagan', ' Sagan Peter', '30', 'BORA - hansgrohe', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '164', 'rider/jens-debusschere', ' Debusschere Jens', '30', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '117', 'rider/anthony-turgis', ' Turgis Anthony', '25', 'Team Total Direct Energie', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '55', 'rider/pierre-latour', ' Latour Pierre', '26', 'AG2R La Mondiale', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '14', 'rider/nacer-bouhanni', ' Bouhanni Nacer', '29', 'Team Arkéa Samsic', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '152', 'rider/aime-de-gendt', 'De Gendt Aimé', '25', 'Circus - Wanty Gobert', '', '', ',,']
# ERROR: ['DNF', '', '+ - 27:14:23', '107', 'rider/sep-vanmarcke', ' Vanmarcke Sep', '31', 'EF Pro Cycling', '', '', ',,']
# ERROR: ['DNS', '', '+ - 27:14:23', '133', 'rider/jenthe-biermans', ' Biermans Jenthe', '24', 'Israel Start-Up Nation', '', '', ',,']
# ERROR: ['DNS', '', '+ - 27:14:23', '138', 'rider/tom-van-asbroeck', 'Van Asbroeck Tom', '29', 'Israel Start-Up Nation', '', '', ',,']
# ERROR: ['DNS', '', '+ - 27:14:23', '68', 'rider/roger-kluge', ' Kluge Roger', '34', 'Lotto Soudal', '', '', ',,']
# ERROR: ['DNS', '', '+ - 27:14:23', '127', 'rider/ben-o-connor', " O'Connor Ben", '24', 'NTT Pro Cycling', '', '', ',,']
# ERROR: ['DNS', '', '+ - 27:14:23', '2', 'rider/mads-pedersen', ' Pedersen Mads', '24', 'Trek - Segafredo', '', '', ',,']
# ERROR: ['DNS', '', '+ - 27:14:23', '131', 'rider/nils-politt', ' Politt Nils', '26', 'Israel Start-Up Nation', '', '', ',,']
# UPDATING 1:gc has 1 participants
# ERROR: ['..', '2', '2', '-', '93', 'rider/tiesj-benoot', ' Benoot Tiesj', '26', 'Team Sunweb', '400', '190']
# ERROR: ['0:18', '..', '3', '3', '-', '101', 'rider/sergio-higuita', ' Higuita Sergio', '22', 'EF Pro Cycling', '325']
# UPDATING 1:green has 1 participants
# UPDATING 1:youth has 0 participants
# 18 in 190: race/paris-nice/2020/stage-6
# UPDATING 1:stage has 98 participants
# ERROR: ['DNF', '', '+ - 22:46:24', '33', 'rider/jean-pierre-drucker', ' Drucker Jempy', '33', 'BORA - hansgrohe', '', '', '-']
# ERROR: ['DNF', '', '+ - 22:46:24', '137', 'rider/mads-wurtz-schmidt', ' Würtz Schmidt Mads', '25', 'Israel Start-Up Nation', '', '', ',,']
# ERROR: ['DNF', '', '+ - 22:46:24', '121', 'rider/giacomo-nizzolo', ' Nizzolo Giacomo', '31', 'NTT Pro Cycling', '', '', ',,']
# ERROR: ['DNF', '', '+ - 22:46:24', '5', 'rider/ryan-mullen', ' Mullen Ryan', '25', 'Trek - Segafredo', '', '', ',,']
# ERROR: ['DNF', '', '+ - 22:46:24', '153', 'rider/tom-devriendt', ' Devriendt Tom', '28', 'Circus - Wanty Gobert', '', '', ',,']
# ERROR: ['DNF', '', '+ - 22:46:24', '115', 'rider/julien-simon', ' Simon Julien', '34', 'Team Total Direct Energie', '', '', ',,']
# ERROR: ['DNF', '', '+ - 22:46:24', '165', 'rider/cyril-gautier', ' Gautier Cyril', '32', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ERROR: ['DNF', '', '+ - 22:46:24', '112', 'rider/niccolo-bonifazio', ' Bonifazio Niccolò', '26', 'Team Total Direct Energie', '', '', ',,']
# ERROR: ['DNF', '', '+ - 22:46:24', '167', 'rider/kevin-reza', ' Reza Kévin', '31', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ERROR: ['DNF', '', '+ - 22:46:24', '96', 'rider/nils-eekhoff', ' Eekhoff Nils', '22', 'Team Sunweb', '', '', ',,']
# ERROR: ['DNF', '', '+ - 22:46:24', '135', 'rider/hugo-hofstetter', ' Hofstetter Hugo', '26', 'Israel Start-Up Nation', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '82', 'rider/pello-bilbao', ' Bilbao Pello', '30', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '136', 'rider/krists-neilands', ' Neilands Krists', '25', 'Israel Start-Up Nation', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '88', 'rider/jan-tratnik', ' Tratnik Jan', '30', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '81', 'rider/dylan-teuns', ' Teuns Dylan', '28', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '132', 'rider/rudy-barbier', ' Barbier Rudy', '27', 'Israel Start-Up Nation', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '71', 'rider/elia-viviani', ' Viviani Elia', '31', 'Cofidis, Solutions Crédits', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '85', 'rider/heinrich-haussler', ' Haussler Heinrich', '36', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '84', 'rider/ivan-garcia-cortina', ' García Cortina Iván', '24', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '66', 'rider/caleb-ewan', ' Ewan Caleb', '25', 'Lotto Soudal', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '86', 'rider/domen-novak', ' Novak Domen', '24', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '83', 'rider/damiano-caruso', ' Caruso Damiano', '32', 'Bahrain - McLaren', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '63', 'rider/jasper-de-buyst', 'De Buyst Jasper', '26', 'Lotto Soudal', '', '', ',,']
# ERROR: ['DNS', '', '+ - 22:46:24', '87', 'rider/hermann-pernsteiner', ' Pernsteiner Hermann', '29', 'Bahrain - McLaren', '', '', ',,']
# UPDATING 1:gc has 98 participants
# UPDATING 1:green has 36 participants
# UPDATING 1:youth has 15 participants
# UPDATING 1:kom has 23 participants
# UPDATING 1:teams has 16 participants
# 19 in 190: race/paris-nice/2020/stage-5
# UPDATING 1:stage has 122 participants
# ERROR: ['DNF', '', '+ - 18:49:00', '32', 'rider/pascal-ackermann', ' Ackermann Pascal', '26', 'BORA - hansgrohe', '', '', '-']
# ERROR: ['DNF', '', '+ - 18:49:00', '141', 'rider/julien-el-fares', 'El Fares Julien', '34', 'NIPPO DELKO One Provence', '', '', ',,']
# ERROR: ['DNF', '', '+ - 18:49:00', '17', 'rider/diego-rosa', ' Rosa Diego', '30', 'Team Arkéa Samsic', '', '', ',,']
# ERROR: ['DNF', '', '+ - 18:49:00', '108', 'rider/michael-woods', ' Woods Michael', '33', 'EF Pro Cycling', '', '', ',,']
# ERROR: ['DNF', '', '+ - 18:49:00', '103', 'rider/lawson-craddock', ' Craddock Lawson', '28', 'EF Pro Cycling', '', '', ',,']
# ERROR: ['DNF', '', '+ - 18:49:00', '56', 'rider/oliver-naesen', ' Naesen Oliver', '29', 'AG2R La Mondiale', '', '', ',,']
# ERROR: ['DNF', '', '+ - 18:49:00', '162', 'rider/frederik-backaert', ' Backaert Frederik', '29', 'B&B Hotels - Vital Concept p/b KTM', '', '', ',,']
# ERROR: ['DNS', '', '+ - 18:49:00', '106', 'rider/tejay-van-garderen', 'van Garderen Tejay', '31', 'EF Pro Cycling', '', '', ',,']
# UPDATING 1:gc has 122 participants
# UPDATING 1:green has 42 participants
# UPDATING 1:youth has 18 participants
# UPDATING 1:kom has 14 participants
# UPDATING 1:teams has 17 participants
# 20 in 190: race/paris-nice/2020/stage-4
# (ITT)
# UPDATING 1:stage has 130 participants
# UPDATING 1:gc has 0 participants
# 21 in 190: race/paris-nice/2020/stage-3
# UPDATING 1:stage has 133 participants
# UPDATING 1:gc has 133 participants
# UPDATING 1:green has 29 participants
# UPDATING 1:youth has 18 participants
# UPDATING 1:kom has 10 participants
# UPDATING 1:teams has 17 participants
# 22 in 190: race/paris-nice/2020/stage-2
# UPDATING 1:stage has 133 participants
# UPDATING 1:gc has 1 participants
# UPDATING 1:green has 1 participants
# UPDATING 1:youth has 1 participants
# ERROR: ['▲6', '101', 'rider/sergio-higuita', ' Higuita Sergio', '22', 'EF Pro Cycling', '0:23', '..', '5', '8', '▲3']
# UPDATING 1:kom has 1 participants
# UPDATING 1:teams has 1 participants
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-307-50d1ce3ce1e2> in <module>
#      32     stage_url = 'https://www.procyclingstats.com/{}'.format(url)
#      33     #stage_url = 'https://www.procyclingstats.com/race/tour-de-france/2020/stage-2'
# ---> 34     rdf = get_points(stage_url)
#      35     all_races.append(rdf)
#      36     #if count == 5: break
#
# <ipython-input-307-50d1ce3ce1e2> in get_points(url)
#      19         result_type = OTHER_TOUR_STAGE
#      20         data_row_length = {'stage': 11, 'gc': 11, 'green': 10, 'youth': 11, 'kom': 10, 'teams': 6}
# ---> 21     data = get_stage_data(stage_html, data_row_length)
#      22     df = build_df(data, result_type)
#      23     return df
#
# <ipython-input-297-2a04bfe31889> in get_stage_data(html, data_row_length)
#      62                 last_ix = 1
#      63                 try:
# ---> 64                     row_length = data_row_length[datasets[data_id]]
#      65                 except KeyError:
#      66                     break
#
# IndexError: list index out of range

# %%
# remove the race headings
print(riders_df.shape)
riders_df = riders_df[(riders_df.distance != '') & (riders_df.gc_pos != '')]
riders_df.drop(['uci'], axis = 1, inplace=True)
print(riders_df.shape)
riders_df.head(10)
# Out:
# (5462, 9)
# (3492, 8)
#      date  pos gc_pos                                           stage  \
# 1   04.09  152    142                      Stage 7 - Millau › Lavaur
# 2   03.09  147    139               Stage 6 - Le Teil › Mont Aigoual
# 3   02.09   14    135                         Stage 5 - Gap › Privas
# 4   01.09  158    138         Stage 4 - Sisteron › Orcières-Merlette
# 5   31.08   15    127                      Stage 3 - Nice › Sisteron
# 6   30.08  137    129                          Stage 2 - Nice › Nice
# 7   29.08    1      1                          Stage 1 - Nice › Nice
# 12  15.08  138    135                       Stage 4 - Ugine › Megève
# 13  14.08  151    144  Stage 3 - Corenc › Saint-Martin-de-Belleville
# 14  13.08  135    142                Stage 2 - Vienne › Col de Porte
#
#    distance  pcs                rider  race_id
# 1       168        kristoff alexander        0
# 2       191        kristoff alexander        0
# 3       183    2   kristoff alexander        0
# 4     160.5        kristoff alexander        0
# 5       198    1   kristoff alexander        0
# 6       186        kristoff alexander        0
# 7       156  100   kristoff alexander        0
# 12    148.5        kristoff alexander        1
# 13      157        kristoff alexander        1
# 14      135        kristoff alexander        1

# %%
#DNF=Did not finish / DNS=Did not start / OTL = Outside time limit / DF
riders_df[riders_df.pos =='DF']
# Out:
# Empty DataFrame
# Columns: [date, pos, gc_pos, stage, distance, rider, race_id]
# Index: []

# %%
#result.groupby(['race', 'stage']).count()[['pos']]
#all_df['rc'] = np.where(all_df['distance']=='', all_df['race'], '')
